# %% [markdown]
# ## Attempt to make a factory that is REST and BLUES compatible

# %% [markdown]
# we need to be able to make a factory that will take a hybrid system and generate another hybrid system with different alchemical regions (not unlike the openmmtools `AlchemicalRegion`) but something that is specific to perses...

# %% [markdown]
# ### Generate a test system to play with...

# %%
from pkg_resources import resource_filename
from simtk.openmm import app
import mdtraj as md
from perses.tests.test_topology_proposal import generate_atp, generate_dipeptide_top_pos_sys
from openmmtools.constants import kB

# %%
atp, sys_generator = generate_atp('solvent')
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
htf = generate_dipeptide_top_pos_sys(atp.topology, 'THR', atp.system, atp.positions, sys_generator, conduct_htf_prop=True)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{4: 4, 9: 9}]
# INFO:proposal_generator:{4: 4, 9: 9}
# INFO:proposal_generator:Only one map so returning that one
# INFO:proposal_generator:{4: 4, 9: 9}
# making topology proposal
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 7
# INFO:geometry:Atom index proposal order is [14, 18, 13, 15, 17, 16, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 1654 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 2])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -12.86077001571492
# generating geometry engine
# making geometry proposal from ALA to THR
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context new positions
# INFO:geometry:There are 7 new atoms
# INFO:geometry:	reduced angle potential = 0.3207298704664604.
# INFO:geometry:	reduced angle potential = 0.8296037253805977.
# INFO:geometry:	reduced angle potential = 0.8428861736212329.
# INFO:geometry:	reduced angle potential = 0.2722113258892962.
# INFO:geometry:	reduced angle potential = 0.013802270949301317.
# INFO:geometry:	reduced angle potential = 1.4359550127544938.
# INFO:geometry:	reduced angle potential = 0.29519040674516484.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CPU
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# INFO:geometry:total reduced potential before atom placement: 16.81404844848707
# INFO:geometry:total reduced energy added from growth system: -50.96737942422681
# INFO:geometry:final reduced energy -34.153330975739706
# INFO:geometry:sum of energies: -34.15333097573974
# INFO:geometry:magnitude of difference in the energies: 3.552713678800501e-14
# INFO:geometry:Final logp_proposal: 32.38298872713841
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 3
# INFO:geometry:Atom index proposal order is [13, 12, 11]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CPU
# added energy components: [('CustomBondForce', 2.4060417983027524), ('CustomAngleForce', 5.986601760579185), ('CustomTorsionForce', 12.147564683538652), ('CustomBondForce', -71.5075876666474)]
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 1631 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.0875963352323845
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context old positions
# INFO:geometry:There are 3 new atoms
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CPU
# INFO:geometry:total reduced potential before atom placement: 16.81404844848707
# INFO:geometry:total reduced energy added from growth system: 8.81651504972902
# INFO:geometry:final reduced energy 25.630563498216084
# INFO:geometry:sum of energies: 25.63056349821609
# INFO:geometry:magnitude of difference in the energies: 7.105427357601002e-15
# INFO:geometry:Final logp_proposal: 14.68731362809471
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce', 'MonteCarloBarostat'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 4
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:Added MonteCarloBarostat.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.56477354, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.56477354, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.56477354), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x7fd13f371cf0> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is PME or Ewald
# INFO:relative:	_add_nonbonded_force_terms: 4 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 2 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x7fd13f3714e0> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CPU
# added energy components: [('CustomBondForce', 0.0), ('CustomAngleForce', 0.00017809232534266413), ('CustomTorsionForce', 0.004336750525590176), ('CustomBondForce', 8.812000206878086)]
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# conducting subsequent work with the following platform: Reference
# conducting subsequent work with the following platform: CPU
# 			HarmonicBondForce: 0.03455153971697946
# 			HarmonicAngleForce: 0.6072017723642879
# 			PeriodicTorsionForce: 16.176809979256742
# 			NonbondedForce: -787.1815412648674
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0
# conducting subsequent work with the following platform: CPU
# 			CustomBondForce: 0.03455153971697946
# 			HarmonicBondForce: 2.4060417983027524
# 			CustomAngleForce: 0.6070236800389454
# 			HarmonicAngleForce: 5.986779852904526
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 28.3243746627954
# 			NonbondedForce: -851.18762483987
# 			CustomNonbondedForce: -7.502721580054732
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0
# conducting subsequent work with the following platform: CPU
# 			CustomBondForce: 0.03455153971697946
# 			HarmonicBondForce: 2.4060417983027524
# 			CustomAngleForce: 0.6070236800389454
# 			HarmonicAngleForce: 5.986779852904526
# 			CustomTorsionForce: 0.0
# 			PeriodicTorsionForce: 28.3243746627954
# 			NonbondedForce: -797.4091104713337
# 			CustomNonbondedForce: 1965.3546136696214
# 			CustomBondForce: 0.0
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0
# conducting subsequent work with the following platform: CPU
# 			HarmonicBondForce: 2.440593338019732
# 			HarmonicAngleForce: 6.593625440618129
# 			PeriodicTorsionForce: 28.320037912269814
# 			NonbondedForce: 1159.1330388197505
# 			AndersenThermostat: 0.0
# 			MonteCarloBarostat: 0.0
# zero state error : 7.815970093361102e-12
# one state error : 2.446398639222025e-11

# %%
zero_params = thermostate.get_parameters()
one_params = {key:1.0 for key in zero_params.keys()}
thermostate.set_parameters(one_params)
print(thermostate.reduced_potential(particle_state))
print(compute_potential_components(thermostate._internal_context, beta=beta))
# Out:
# -9828.703974410073
# conducting subsequent work with the following platform: CPU
# [('CustomBondForce', 1.6990917187937111), ('HarmonicBondForce', 0.09913696074813351), ('CustomAngleForce', 2.319934470551809), ('HarmonicAngleForce', 2.3934122724695435), ('CustomTorsionForce', 0.0), ('PeriodicTorsionForce', 23.291193225113936), ('NonbondedForce', -9858.240754338867), ('CustomNonbondedForce', -0.6787117536650924), ('CustomBondForce', 0.0), ('AndersenThermostat', 0.0), ('MonteCarloBarostat', 0.0)]

# %%
from simtk import openmm
#######LOGGING#############################
import logging
logging.basicConfig(level = logging.NOTSET)
_logger = logging.getLogger("repartition")
_logger.setLevel(logging.DEBUG)


class RepartitionHybridSystem():
    """
    repartition the hybrid system into forces that are select, interselect, nonselect
    """
    allowable_force_objects = ['HarmonicBondForce', 'CustomBondForce', 'HarmonicAngleForce', 'CustomAngleForce', 'PeriodicTorsionForce', 'CustomTorsionForce', 'NonbondedForce', 'CustomNonbondedForce', 'MonteCarloBarostat']
    custom_expressions = {
        'CustomBondForce': '(K/2)*(r-length)^2;'+'K = (1-lambda_bonds)*K1 + lambda_bonds*K2;'+'length = (1-lambda_bonds)*length1 + lambda_bonds*length2;',
        'CustomAngleForce': None,
        'CustomTorsionForce': None}
    
    custom_force_templates = {'CustomBondForce': openmm.CustomBondForce,
                             'CustomAngleForce': openmm.CustomAngleForce,
                             'CustomTorsionForce': openmm.CustomTorsionForce}
    standard_valence_force_name_maps = {'CustomBondForce': 'HarmonicBondForce',
                                       'CustomAngleForce': 'HarmonicAngleForce',
                                       'CustomTorsionForce': 'PeriodicTorsionForce'}
                         
    valence_method_query = {'CustomBondForce': {'number_terms': 'getNumBonds',
                                                'number_per_params': 'getNumPerBondParameters',
                                                'per_term_parameter_name': 'getPerBondParameterName',
                                                'params' : 'getBondParameters', 
                                                'add_per_param': 'addPerBondParameter',
                                                'add_term': 'addBond'},
                              'CustomAngleForce': {'number_terms': 'getNumAngles',
                                                    'number_per_params': 'getNumPerAngleParameters',
                                                    'per_term_parameter_name': 'getPerAngleParameterName',
                                                    'params' : 'getAngleParameters', 
                                                    'add_per_param': 'addPerAngleParameter',
                                                    'add_term': 'addAngle'},
                              'CustomTorsionForce': {'number_terms': 'getNumTorsions',
                                                    'number_per_params': 'getNumPerTorsionParameters',
                                                    'per_term_parameter_name': 'getPerTorsionParameterName',
                                                    'params' : 'getTorsionParameters', 
                                                    'add_per_param': 'addPerTorsionParameter',
                                                    'add_term': 'addTorsion'}}
    num_particles_by_force = {'CustomBondForce': 2, 'CustomAngleForce' : 3, 'CustomTorsionForce': 4}
    tri_template_lambdas = ['select', 'interselect', 'nonselect']
    added_custom_forces = {}
    lambda_caller='lambda_'
    default_select_lambda=1.
    
    #primary nonbonded force
    from openmmtools.constants import ONE_4PI_EPS0 as coulomb_const
    standard_nonbonded_mixing_expression = [
        f"mixer*(U_electrostatics + U_sterics);",
        f"U_sterics = 4*epsilon*((sigma/r)^12-(sigma/r)^6); sigma=0.5*(sigma1+sigma2); epsilon=sqrt(epsilon1*epsilon2);",
        f"U_electrostatics = {coulomb_const}*charge1*charge2/r;",
        f"mixer = lambda_select*selected + lambda_nonselect*nonselected + lambda_interselect*interselected;"]
    primary_nonbonded_template = "4*epsilon*((sigma/r)^12-(sigma/r)^6); sigma=0.5*(sigma1+sigma2); epsilon=sqrt(epsilon1*epsilon2)"
    standard_nonbonded_mixing_expression = "U_sterics = 4*epsilon*x*(x-1.0); x = (sigma/reff_sterics)^6;"
    
    @classmethod
    def create_system(cls, hybrid_factory, selection_indices):
        """
        initialize a system
        """
        out_system = openmm.System()
        setattr(cls, 'hybrid_factory', hybrid_factory)
        setattr(cls, 'out_system', out_system)
        setattr(cls, 'in_system', hybrid_factory._hybrid_system)
        
        #create a force dictionary
        cls.create_force_dict()
        
        #handle some preliminary stuff
        cls.add_particles(selection_indices)
        cls.add_constraints()
        cls.add_virtual_sites()
        cls.handle_barostat()
        
        #iterate over each force object and attempt to convert the force into 3 forces.
        #add the valence forces appropriately.
        for force_name in cls.standard_valence_force_name_maps.keys():
            cls.add_valence_force(force_name)
            cls.handle_valence_force(force_name)
        
        #now for the nonbonded forces...
        #handle the standard nonbonded force...
        #cls.add_nonbonded_force()
        
        
        return cls.out_system
        
        
    
    @classmethod
    def create_force_dict(cls):
        _dict= {idx: (type(force).__name__, force) for idx, force in enumerate(cls.in_system.getForces())}
        force_names = [val[0] for val in _dict.values()]
        if not set(force_names).issubset(set(cls.allowable_force_objects)):
            raise Exception(f"there is an unknown force object in the input system")
        setattr(cls, 'force_dict', _dict)
        _logger.debug(f"created force dict: ")
        for key, item in cls.force_dict.items():
            _logger.debug(f"\t {key}: {item}")
    
    @classmethod
    def add_particles(cls, selection_indices):
        """
        add particles
        """
        _logger.debug(f"adding particles and creating selection dictionary")
        #add particles
        num_particles = cls.in_system.getNumParticles()
        _logger.debug(f"hybrid system contains {num_particles} particles")
        for particle_idx in range(num_particles):
            mass = cls.in_system.getParticleMass(particle_idx)
            cls.out_system.addParticle(mass)
        
        nonselection_indices = [idx for idx in range(num_particles) if idx not in selection_indices]
        assert set(selection_indices).union(set(nonselection_indices)) == set(range(num_particles))
        setattr(cls, 'select_indices', selection_indices)
        setattr(cls, 'nonselect_indices', nonselection_indices)
        
        
    
    @classmethod
    def add_box_vectors(cls):
        #copy box vectors
        box_vectors = cls.in_system.getDefaultPeriodicBoxVectors()
        cls.out_system.setDefaultPeriodicBoxVectors(*box_vectors)
    
    @classmethod
    def add_constraints(cls):
        """add constraints"""
        #constraints
        num_constraints = cls.in_system.getNumConstraints()
        _logger.debug(f"adding {num_constraints} constraints")
        
        for constraint_idx in range(num_constraints):
            a0, a1, length=cls.in_system.getConstraintParameters(constraint_idx)
            cls.out_system.addConstraint(a0, a1, length)
    
    @classmethod
    def add_virtual_sites(cls):
        _logger.debug(f"adding virtual sites")
        for particle_idx in range(cls.in_system.getNumParticles()):
            if cls.in_system.isVirtualSite(particle_idx):
                virtual_site = cls.in_system.getVirtualSite(particle_idx)
                cls.out_system.setVirtualSite(particle_idx, virtual_site)
    
    @classmethod
    def handle_barostat(cls):
        force_names = [val[0] for val in cls.force_dict.values()]
        if 'MonteCarloBarostat' in force_names:
            _logger.debug(f"found a MonteCarloBarostat; adding to 'out_system'")
            import copy
            barostat_force_index = cls.find_valence_custom_force(custom_force_name='MonteCarloBarostat')
            barostat_force = cls.force_dict[barostat_force_index][1]
            copy_barostat = copy.deepcopy(barostat_force)
            cls.out_system.addForce(copy_barostat)
        else:
            _logger.debug(f"did not find a MonteCarloBarostat.")
    
    @classmethod
    def add_valence_force(cls, force_name):
        """
        NOTE: the standard force does not interpolate parameters whereas the customforce does;
        what we have to do is create 3 of each flavor of force (one for 'select/nonselect/interselect' interaction)
        for each pair of ('HarmonicBondForce/CustomBondForce', 'HarmonicAngleForce/CustomAngleForce', 'PeriodicTorsionForce/CustomTorsionForce'),
        do the following:
        1. pull the appropriate query force (standard/custom)
        2. query the global parameters and per-term parameters
        3. modify the energy function
        4. add the appropriate global params and per particle params to each force
        5. add the lambda_{select/nonselect/interselect}
        6. add the force to the out_system
        """
        _logger.debug(f"adding valence equivalents of {force_name}")
        #get the force index and the force
        custom_valence_force_index = cls.find_valence_custom_force(force_name, cls.custom_expressions[force_name])
        custom_valence_force = cls.force_dict[custom_valence_force_index][1]
        _logger.debug(f"force yanked: {custom_valence_force}")
        
        #tally the number of global params and per bond params
        num_global_params = custom_valence_force.getNumGlobalParameters()
        num_per_term_params = getattr(custom_valence_force, cls.valence_method_query[force_name]['number_per_params'])()
        _logger.debug(f"found {num_global_params} global parameters")
        _logger.debug(f"found {num_per_term_params} per term parameters")
        
        #pbc?
        pbc = custom_valence_force.usesPeriodicBoundaryConditions()
        _logger.debug(f"periodic boundary conditions: {pbc}")
        
        # query the global/per bond parameters
        global_params_values = [(custom_valence_force.getGlobalParameterName(idx), custom_valence_force.getGlobalParameterDefaultValue(idx)) for idx in range(num_global_params)]
        per_term_params = [getattr(custom_valence_force, cls.valence_method_query[force_name]['per_term_parameter_name'])(idx) for idx in range(num_per_term_params)]
        _logger.debug(f"global parameters: {global_params_values}")
        _logger.debug(f"per term parameters: {per_term_params}")
        
        #add a force
        force_expression = cls.custom_expressions[force_name]
        if force_expression is None:
            force_expression = custom_valence_force.getEnergyFunction()
        _logger.debug(f"queried force (energy) expression: {force_expression}")
        
        #make the energy function dependent on lambda_{select/interselect/nonselect}
        splittd_expression = force_expression.split(';')
        mod_first_expression = cls.lambda_caller+'{partition}'+'*('+splittd_expression[0]+')'
        splittd_expression[0] = mod_first_expression
        add_custom_valence_force_expressions = {partition: ';'.join(splittd_expression).format(partition=partition) for partition in cls.tri_template_lambdas}
        _logger.debug(f"custom force expressions: {add_custom_valence_force_expressions}")
        add_custom_valence_forces = {partition: cls.custom_force_templates[force_name](add_custom_valence_force_expressions[partition]) for partition in cls.tri_template_lambdas}
        
        #add corresponding global parameters to the force and per term parameters
        for idx, key in enumerate(add_custom_valence_forces.keys()):
            cforce = add_custom_valence_forces[key]
            _logger.debug(f"adding force: {key} --> {cforce}")
            for param, val in global_params_values:
                _logger.debug(f"global param: {param}; value: {val}")
                cforce.addGlobalParameter(param, val)
            new_global_param = cls.lambda_caller+key
            _logger.debug(f"adding new global param: {new_global_param}")
            cforce.addGlobalParameter(new_global_param, 1.)
            cforce.setUsesPeriodicBoundaryConditions(pbc)
            for param in per_term_params: 
                _logger.debug(f"adding per_term param: {param}")
                getattr(cforce, cls.valence_method_query[force_name]['add_per_param'])(param)
            cls.out_system.addForce(cforce)
        
        cls.added_custom_forces[force_name] = add_custom_valence_forces
    

        
    @classmethod
    def handle_valence_force(cls, force_name):
        """
        copy the appropriate terms over from the standard/custom force and write to the new custom force 
        """
        _logger.debug(f"handling {force_name}")
        
        #get the force index and the force to query
        custom_valence_force_index = cls.find_valence_custom_force(force_name, cls.custom_expressions[force_name])
        custom_query_force = cls.force_dict[custom_valence_force_index][1]
        standard_query_force_index = cls.find_valence_custom_force(cls.standard_valence_force_name_maps[force_name])
        standard_query_force_name, standard_query_force = cls.force_dict[standard_query_force_index]
        _logger.debug(f"querying custom valence force: {custom_query_force}")
        _logger.debug(f"querying standard valence force: {standard_query_force}")
        
        for force in [custom_query_force, standard_query_force]:
            _logger.debug(f"querying {force}")
            custom_type = True if 'Custom' in force.__class__.__name__ else False
            _logger.debug(f"is custom: {custom_type}")

            number_terms = getattr(force, cls.valence_method_query[force_name]['number_terms'])()
            _logger.debug(f"there are {number_terms} in this force")
            num_particles = cls.num_particles_by_force[force_name]
            _logger.debug(f"there are {num_particles} particles in each terms")
            add_forces = cls.added_custom_forces[force_name] #add the force...
            num_per_term_params = getattr(custom_query_force, cls.valence_method_query[custom_query_force.__class__.__name__]['number_per_params'])()
            for term_index in range(number_terms):
                queries = getattr(force, cls.valence_method_query[force_name]['params'])(term_index)
                particles, parameters = queries[:num_particles], queries[num_particles:]
                if custom_type:
                    argument = (*particles, *parameters)
                else:
                    reduced_parameters = []
                    for param in parameters:
                        try:
                            out_param = param/param.unit
                        except Exception as e:
                            out_param = param
                        reduced_parameters.append(out_param)
                        
                    argument = (*particles, reduced_parameters+reduced_parameters)
                    
                _logger.debug(f"particles: {particles}")
                _logger.debug(f"query term parameters: {parameters}")
                _logger.debug(f"add term input: {argument}")
                
                #get the number of per term params...
                assert len(argument[-1]) == num_per_term_params
                
                if set(particles).issubset(set(cls.select_indices)):
                    getattr(add_forces['select'], cls.valence_method_query[force_name]['add_term'])(*argument)
                elif set(particles).issubset(set(cls.nonselect_indices)):
                    #add_forces['nonselect'].addBond(index1, index2, [r0, k, r0, k])
                    getattr(add_forces['nonselect'], cls.valence_method_query[force_name]['add_term'])(*argument)
                else:
                    assert set(particles).intersection(set(cls.nonselect_indices)) != set() and set(particles).intersection(set(cls.select_indices)) != set()
                    #cls.bonded_terms['lambda_interselect'].addBond(index1, index2, [r0, k, r0, k])
                    getattr(add_forces['interselect'], cls.valence_method_query[force_name]['add_term'])(*argument)
         
    @classmethod
    def find_valence_custom_force(cls, custom_force_name, custom_expression_matcher=None):
        force_indices = [idx for idx in cls.force_dict.keys() if cls.force_dict[idx][0] == custom_force_name]
        if custom_expression_matcher is not None:
            particulars_forces = [idx for idx in force_indices if cls.force_dict[idx][1].getEnergyFunction() == custom_expression_matcher]
        else:
            particulars_forces = force_indices
        assert len(particulars_forces) == 1
        return particulars_forces[0]
    
    @classmethod
    def handle_nonbonded_parameters(cls, nonbonded_query_force, to_force):
        #nonbonded method
        nbm = nonbonded_query_force.getNonbondedMethod()
        _logger.debug(f"found nonbondedmethod: {nbm}")
        to_force.setNonbondedMethod(nbm)

        #reaction field dielectric
        try:
            rxn = nonbonded_query_force.getReactionFieldDielectric()
            to_force.setReactionFieldDielectric(rxn)
        except Exception as e:
            _logger.debug(f"failed to query/set reaction field dielectric of {nonbonded_query_force}")
        
    
        #cutoff
        cutoff = nonbonded_query_force.getCutoffDistance()
        to_force.setCutoffDistance(cutoff)
        
        #switching distance
        uses_switch_function = nonbonded_query_force.getUseSwitchingFunction()
        if uses_switch_function:
            distance = nonbonded_query_force.getSwitchingDistance()
            to_force.setUseSwitchingFunction(True)
            to_force.setSwitchingDistance(distance)
        else:
            to_force.setUseSwitchingFunction(False)
        
        #pme and ewald
        try:
            pmeparam = nonbonded_query_force.getPMEParameters()
            ewalderr = nonbonded_query_force.getEwaldErrorTolerance()
            to_force.setPMEParameters(*pmeparam)
            to_force.setEwaldErrorTolerance(ewalderr)
        except Exception as e:
            _logger.debug(f"failed to query/set PME and Ewald parameters of {nonbonded_query_force}")
        
        #dispersion
        try:
            disp = nonbonded_query_force.getUseDispersionCorrection()
            to_force.setUseDispersionCorrection(disp)
        except Exception as e:
            _logger.debug(f"failed to query/set dispersion of {nonbonded_query_force}")
        
        #long range
        try:
            corr = nonbonded_query_force.getUseLongRangeCorrection()
            to_force.setUseLongRangeCorrection(corr)
        except Exception as e:
            _logger.debug(f"failed to query/set long range correction of {nonbonded_query_force}")
    
#     @classmethod
#     def handle_custom_nonbonded_parameters(cls, nonbonded_query_force, to_force):
#         #nbm
#         nbm = nonbonded_query_force.getNonbondedMethod()
#         to_force.setNonbondedMethod(nbm)
        
#         #
    
#     @classmethod
#     def handle_custom_nonbonded_translation(cls, nonbonded_query_force, to_customnonbonded):
#         switch = nonbonded_query_force.getUseSwitchingFunction()
#         to_customnonbonded.setUseSwitchingFunction(switch)
#         switch_distance = nonbonded_query_force.getSwitchingDistance()
#         to_customnonbonded.setSwitchingDistance(switch_distance)
        
#         disp = nonbonded_query_force.getUseDispersionCorrection()
#         to_customnonbonded.setUseLongRangeCorrection(disp)
        
#         nbm = nonbonded_query_force.getNonbondedMethod()
#         to_customnonbonded.setNonbondedMethod(nbm)
    
    @classmethod
    def get_nonselect_expression(cls):
        #make deepcopies of the nonbonded force and add appropriate mixing global params...
        from openmmtools.constants import ONE_4PI_EPS0
        nonselect_expression = "mixer*(U_electrostatics + U_sterics);"
        nonselect_expression += f"U_electrostatics = (1 - select_atoms_bool)*{ONE_4PI_EPS0}*charge_one*charge_two/r;"
        LJ_v2 = cls.hybrid_factory._softcore_LJ_v2
        if LJ_v2:
            nonselect_expression += "U_sterics = select(step(r - r_LJ), 4*epsilon*x*(x-1.0), U_sterics_quad);"
            nonselect_expression += "U_sterics_quad = Force*(((r - r_LJ)^2)/2 - (r - r_LJ)) + U_sterics_cut;"
            nonselect_expression += "U_sterics_cut = 4*epsilon*((sigma/r_LJ)^6)*(((sigma/r_LJ)^6) - 1.0);"
            nonselect_expression += "Force = -4*epsilon*((-12*sigma^12)/(r_LJ^13) + (6*sigma^6)/(r_LJ^7));"
            nonselect_expression += "x = (sigma/r)^6;"
            nonselect_expression += "r_LJ = softcore_alpha*((26/7)*(sigma^6)*lambda_sterics_deprecated)^(1/6);"
            nonselect_expression += "lambda_sterics_deprecated = new_interaction*(1.0 - lambda_sterics_insert) + old_interaction*lambda_sterics_delete;"
        else:
            nonselect_expression = "U_sterics = 4*epsilon*x*(x-1.0); x = (sigma/reff_sterics)^6;"
        
        nonselect_expression += "epsilon = (1-lambda_sterics)*epsilonA + lambda_sterics*epsilonB;" #interpolation
        nonselect_expression += "reff_sterics = sigma*((softcore_alpha*lambda_alpha + (r/sigma)^6))^(1/6);" # effective softcore distance for sterics
        nonselect_expression += "sigma = (1-lambda_sterics)*sigmaA + lambda_sterics*sigmaB;"
        nonselect_expression += "charge_one = q_old1 + lambda_electrostatics * (q_new1 - q_old1);"
        nonselect_expression += "charge_two = q_old2 + lambda_electrostatics * (q_new2 - q_old2);"

        nonselect_expression += "lambda_alpha = new_interaction - new_interaction*lambda_sterics_insert + old_interaction*lambda_sterics_delete;"
        nonselect_expression += "lambda_sterics = core_interaction*lambda_sterics_core + new_interaction*lambda_sterics_insert + old_interaction*lambda_sterics_delete;"
        nonselect_expression += "lambda_electrostatics = core_interaction*lambda_electrostatics_core + new_interaction*lambda_electrostatics_insert + old_interaction*lambda_electrostatics_delete;"
        nonselect_expression += "core_interaction = delta(unique_old1 + unique_old2 + unique_new1 + unique_new2); new_interaction = max(unique_new1, unique_new2); old_interaction = max(unique_old1, unique_old2);"
          
        nonselect_expression += f"mixer = lambda_interselect*interselect_atoms_bool + lambda_nonselect*nonselect_atoms_bool + lambda_select*select_atoms_bool;"
        nonselect_expression += f"interselect_atoms_bool = delta(1 - (is_select1 + is_select2)); nonselect_atoms_bool = delta(is_select1 + is_select2);select_atoms_bool = delta(2 - (is_select1 + is_select2));"
        
        nonselect_expression += "epsilonA = sqrt(epsilonA1*epsilonA2);" # mixing rule for epsilon
        nonselect_expression += "epsilonB = sqrt(epsilonB1*epsilonB2);" # mixing rule for epsilon
        nonselect_expression += "sigmaA = 0.5*(sigmaA1 + sigmaA2);" # mixing rule for sigma
        nonselect_expression += "sigmaB = 0.5*(sigmaB1 + sigmaB2)" # mixing rule for sigma
        
        return nonselect_expression
            
    
    @classmethod
    def add_nonbonded_force(cls):
        """
        the nonbonded forces handle all env forces, (elec and steric.)
        as well as unique new/old 
        """
        _logger.debug(f"handling nonbonded_forces")
        import copy
        
        #retrieve the nonbonded query force...
        nonbonded_force_index = cls.find_valence_custom_force('NonbondedForce')
        nonbonded_query_name, nonbonded_query_force = cls.force_dict[nonbonded_force_index]
        _logger.debug(f"pulled standard nonbonded (electrostatic + env) force from hybrid system")
        
        #retrieve the custom nonbonded query force...
        customnonbonded_force_index = cls.find_valence_custom_force('CustomNonbondedForce')
        customnonbonded_query_name, customnonbonded_query_force = cls.force_dict[customnonbonded_force_index]
        _logger.debug(f"pulled custom nonbonded (steric + env) force from hybrid system")
        
        nonselect_expression = cls.get_nonselect_expression()
        nonbonded_forces = {'select': openmm.NonbondedForce()}
        nonbonded_forces['non_select'] = openmm.CustomNonbondedForce(nonselect_expression)
        for key in ['lambda_nonselect', 'lambda_interselect', 'lambda_select']: nonbonded_forces['non_select'].addGlobalParameter(key, 1.)
        
        #add global variables
        _logger.debug(f"adding global parameters to customnonbonded force")
        nonbonded_forces['non_select'].addGlobalParameter("softcore_alpha", cls.hybrid_factory.softcore_alpha)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_sterics_core", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_electrostatics_core", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_sterics_insert", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_sterics_delete", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_electrostatics_insert", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_electrostatics_delete", 0.0)
        
        for key in ['lambda_electrostatics_core', 'lambda_sterics_core', 'lambda_electrostatics_delete', 'lambda_electrostatics_insert']:
            nonbonded_forces['select'].addGlobalParameter(key, 0.)
        #for key in ['lambda_nonselect', 'lambda_interselect', 'lambda_select']: nonbonded_forces['non_select'].addGlobalParameter(key)
        
        #add per particle parameters
        _logger.debug(f"adding per particle parameters to customnonbonded force")
        nonbonded_forces['non_select'].addPerParticleParameter("q_old")
        nonbonded_forces['non_select'].addPerParticleParameter("sigmaA") # Lennard-Jones sigma initial
        nonbonded_forces['non_select'].addPerParticleParameter("epsilonA") # Lennard-Jones epsilon initial
        nonbonded_forces['non_select'].addPerParticleParameter("q_new")
        nonbonded_forces['non_select'].addPerParticleParameter("sigmaB") # Lennard-Jones sigma final
        nonbonded_forces['non_select'].addPerParticleParameter("epsilonB") # Lennard-Jones epsilon final
        nonbonded_forces['non_select'].addPerParticleParameter("unique_old") # 1 = hybrid old atom, 0 otherwise
        nonbonded_forces['non_select'].addPerParticleParameter("unique_new") # 1 = hybrid new atom, 0 otherwise
        nonbonded_forces['non_select'].addPerParticleParameter("is_select") #if it is a selection atom
        
        
        _logger.debug(f"handling nonbonded parameters...")
        cls.handle_nonbonded_parameters(nonbonded_query_force, nonbonded_forces['select'])
        cls.handle_nonbonded_parameters(customnonbonded_query_force, nonbonded_forces['non_select'])
        
        #first, iterate over exceptions...
        num_exceptions = nonbonded_query_force.getNumExceptions()
        num_exception_offsets = nonbonded_query_force.getNumExceptionParameterOffsets()
        exception_offset_exception_indices = [nonbonded_query_force.getExceptionParameterOffset(q)[1] for q in range(num_exception_offsets)]
        num_particle_parameter_offsets = nonbonded_query_force.getNumParticleParameterOffsets()
        num_particles = nonbonded_query_force.getNumParticles()
        assert num_particles == cls.out_system.getNumParticles()
        _logger.debug(f"there are {num_exceptions} standard nonbonded exceptions")
        _logger.debug(f"there are {num_exception_offsets} standard nonbonded offsets")
        _logger.debug(f"there are {num_particle_parameter_offsets} standard nonbonded exception offsets")
        
    
        #first thing to do is add all of the particles to the select_nbf and zero the interactions of all nonselects...
        _logger.debug(f"iterating over particles")
        for particle_idx in range(num_particles):
            #_logger.debug(f"particle: {particle_idx}")
            charge, sigma, epsilon = nonbonded_query_force.getParticleParameters(particle_idx)
            sigmaA, epsilonA, sigmaB, epsilonB, unique_old, unique_new = customnonbonded_query_force.getParticleParameters(particle_idx)
                
            if unique_old == 1:
                assert particle_idx in cls.hybrid_factory._atom_classes['unique_old_atoms']
                #_logger.debug(f"is unique old")
                q_old, q_new = charge, 0.*charge
                assert epsilon/epsilon.unit==0., f"unique old atom has a steric epsilon of {epsilon}"
            elif unique_new == 1:
                assert particle_idx in cls.hybrid_factory._atom_classes['unique_new_atoms']
                #_logger.debug(f"is unique new")
                q_old, q_new = 0*charge, charge
                assert epsilon/epsilon.unit==0., f"unique old atom has a steric epsilon of {epsilon}"
            elif particle_idx in cls.hybrid_factory._atom_classes['core_atoms']:
                #_logger.debug(f"is a core")
                old_idx, new_idx = cls.hybrid_factory._hybrid_to_old_map[particle_idx], cls.hybrid_factory._hybrid_to_new_map[particle_idx]
                [q_old, _, _] = cls.hybrid_factory._old_system_forces['NonbondedForce'].getParticleParameters(old_idx)
                [q_new, _, _] = cls.hybrid_factory._new_system_forces['NonbondedForce'].getParticleParameters(new_idx)
            else: #this is env atom
                #_logger.debug(f"is an environment")
                old_idx, new_idx = cls.hybrid_factory._hybrid_to_old_map[particle_idx], cls.hybrid_factory._hybrid_to_new_map[particle_idx]
                [q_old, sigmaA, epsilonA] = cls.hybrid_factory._old_system_forces['NonbondedForce'].getParticleParameters(old_idx)
                [q_new, sigmaB, epsilonB] = cls.hybrid_factory._new_system_forces['NonbondedForce'].getParticleParameters(new_idx)
                #sanity checks for env atoms
                assert q_old==q_new
                assert sigmaA==sigmaB
                assert epsilonA==epsilonB
                       
            if particle_idx in cls.select_indices:
                #_logger.debug(f"is a selected index")
                is_select=1
                #assert epsilon==0
                if particle_idx in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    assert unique_new==1
                    assert unique_old==0
                    nonbonded_forces['select'].addParticle(0.0, sigma, epsilon*0.0) #start charge at 0
                elif particle_idx in cls.hybrid_factory._atom_classes['unique_old_atoms']:
                    assert unique_new==0
                    assert unique_old==1
                    nonbonded_forces['select'].addParticle(q_old, sigma, epsilon*0.0) #start charge at q_old
                elif particle_idx in cls.hybrid_factory._atom_classes['core_atoms']:
                    assert unique_new==0
                    assert unique_old==0
                    nonbonded_forces['select'].addParticle(q_old, sigma, epsilon*0.0) #start charge at q_old
                elif particle_idx in cls.hybrid_factory._atom_classes['environment_atoms']:
                    assert unique_new==0
                    assert unique_old==0
                    nonbonded_forces['select'].addParticle(q_old, sigma, epsilon)
            else:
                #_logger.debug(f"is a nonselected index")
                is_select=0
                if particle_idx in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    raise Exception(f"unique new atoms must be selected indices")
                elif particle_idx in cls.hybrid_factory._atom_classes['unique_old_atoms']:
                    raise Exception(f"unique old atoms must be selected indices")
                elif particle_idx in cls.hybrid_factory._atom_classes['core_atoms']:
                    raise Exception(f"core atoms must be selected indices")
                elif particle_idx in cls.hybrid_factory._atom_classes['environment_atoms']:
                    nonbonded_forces['select'].addParticle(charge*0., sigma, epsilon*0.) #zero env charges
                else:
                    raise Exception(f"there is a consideration missing")
            
            #regardless, it is added to the non_select custom nonbonded force
            #format is q_old, sigmaA, epsilonA, q_new, sigmaB, epsilonB, unique_old, unique_new, is_select
            nonbonded_forces['non_select'].addParticle([q_old, sigmaA, epsilonA, q_new, sigmaB, epsilonB, unique_old, unique_new, is_select])
        
        #let's just make sure we add the exceptions/exclusions between unique old and new right off the bat
        unique_olds, unique_news = cls.hybrid_factory._atom_classes['unique_old_atoms'], cls.hybrid_factory._atom_classes['unique_new_atoms']
        for old_idx in unique_olds:
            for new_idx in unique_news:
                nonbonded_forces['select'].addException(old_idx, new_idx, 0.0*unit.elementary_charge**2, 1.0*unit.nanometers, 0.0*unit.kilojoules_per_mole)
                nonbonded_forces['non_select'].addExclusion(old_idx, new_idx)
        
        #do the interaction group thing...
        _logger.debug(f"adding interaction group...")
        hf = cls.hybrid_factory
        core_atoms = hf._atom_classes['core_atoms']
        unique_old_atoms = hf._atom_classes['unique_old_atoms']
        unique_new_atoms = hf._atom_classes['unique_new_atoms']
        environment_atoms = hf._atom_classes['environment_atoms']

        nonbonded_forces['non_select'].addInteractionGroup(unique_old_atoms, core_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_old_atoms, environment_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_new_atoms, core_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_new_atoms, environment_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(core_atoms, environment_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(core_atoms, core_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_new_atoms, unique_new_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_old_atoms, unique_old_atoms)
        
        
            
        for exception_idx in range(num_exceptions):
            p1, p2, chargeprod, sigma, epsilon = nonbonded_query_force.getExceptionParameters(exception_idx)
            has_offset = True if exception_idx in exception_offset_exception_indices else False
            #if there is an offset, we can apply the offset to the 
            if set([p1, p2]).issubset(set(cls.select_indices)):      
                if p1 in cls.hybrid_factory._atom_classes['unique_old_atoms'] and p2 in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    #the exception is already handled
                    pass
                elif p2 in cls.hybrid_factory._atom_classes['unique_old_atoms'] and p1 in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    #the exception is already handled
                    pass
                else:
                    #these could be unique old/new exceptions
                    nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon)
                    nonbonded_forces['non_select'].addExclusion(p1, p2)
                   
            elif set([p1, p2]).issubset(set(cls.nonselect_indices)):
                assert set([p1, p2]).issubset(cls.hybrid_factory._atom_classes['environment_atoms'])
                nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon)
                nonbonded_forces['non_select'].addExclusion(p1, p2)
            else:
                #this is interselect
                #all we can do is to write an exclusions for both in the customnonbonded force and add the exception into the
                #custombondedforce
                nonbonded_forces['select'].addException(p1, p2, chargeprod*0.0, sigma, epsilon*0.0)
                nonbonded_forces['non_select'].addExclusion(p1, p2)
        
        #now that all of the standard exceptions are handled, we have to handle the offsets
        #all of the standard parameter offsets go to the nonbonded electrostatic force
        for param_offset_idx in range(num_particle_parameter_offsets):
            #these are all for electrostatics; the the sterics are zeroed appropriately
            param, particle_idx, chargescale, sigmascale, epsilonscale = nonbonded_query_force.getParticleParameterOffset(param_offset_idx)
            assert particle_idx in cls.select_indices
            nonbonded_forces['select'].addParticleParameterOffset(param, particle_idx, chargescale, sigmascale, epsilonscale)
        for exception_offset_idx in range(num_exception_offsets):
            param, exception_idx, chargeprodscale, sigmascale, epsilonscale = nonbonded_query_force.getExceptionParameterOffset(exception_offset_idx)
            p1, p2, chargeprod, sigma, epsilon = nonbonded_query_force.getExceptionParameters(exception_idx)
            assert set([p1, p2]).issubset(set(cls.select_indices))
            nonbonded_forces['select'].addExceptionParameterOffset(param, exception_idx, chargeprodscale, sigmascale, epsilonscale)
            #the scales should be handled appropriately by the nonselect force
        
        #simply copy the custombondforce and apply to the new repartitioned hybrid system
        custombondforce = cls.hybrid_factory._hybrid_system_forces['old_new_exceptions_force']
        cls.out_system.addForce(copy.deepcopy(custombondforce))
        
        #the last thing to do is to add the forces to the out_system
        cls.out_system.addForce(nonbonded_forces['select'])
        cls.out_system.addForce(nonbonded_forces['non_select'])
            
        
        
            
            
                
                
            
        #then add all of the standard exceptions appropriately
        #TODO: check where the sterics force comes in and also omit the exception if there is a parameter offset
#         for exception_idx in range(num_exceptions):
#             p1, p2, chargeprod, sigma, epsilon = nonbonded_query_force.getExceptionParameters(exception_idx)
            
#             has_offset = True if exception_idx in exception_offset_exception_indices else False
#             if set([p1, p2]).issubset(set(cls.nonselect_indices)) and not has_offset:
#                 #add the exception to the nbforce
#                 nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon) #add the exception to the standard force
#                 nonbonded_forces['non_select'].addExclusion(p1, p2)
#             elif set([p1, p2]).issubset(set(cls.select_indices)) and not has_offset:
#                 nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon) #add the exception to the standard force
#                 #the electrostatics are already handled in the CustomNonbondedForce; do not add an exclusion since this will remove the steric
#             else: #this is interselect. (either with or without an offset...)
#                 #this has to go into the custombondforce...possibly with a 
#                 #nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon) #add the exception to the standard force
#                 pass

# %% [markdown]
# have to query the selection indices...

# %% [markdown]
# we have to remove the andersen thermostat

# %%
htf._hybrid_system.getForces()
# Out:
# [<simtk.openmm.openmm.MonteCarloBarostat; proxy of <Swig Object of type 'OpenMM::MonteCarloBarostat *' at 0x7fd14052e660> >,
#  <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e7e0> >,
#  <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x7fd14052e690> >,
#  <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd14052e510> >,
#  <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x7fd14052e4b0> >,
#  <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd14052e600> >,
#  <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x7fd14052e780> >,
#  <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x7fd14052e3f0> >,
#  <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x7fd14052e450> >,
#  <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e810> >]

# %%
hybrid_indices = list(htf._atom_classes['unique_old_atoms']) + list(htf._atom_classes['unique_new_atoms']) + list(htf._atom_classes['core_atoms'])

# %%
repartitioned_system = RepartitionHybridSystem.create_system(htf, hybrid_indices)
# Out:
# DEBUG:repartition:created force dict:
# DEBUG:repartition:	 0: ('MonteCarloBarostat', <simtk.openmm.openmm.MonteCarloBarostat; proxy of <Swig Object of type 'OpenMM::MonteCarloBarostat *' at 0x7fd14052e2a0> >)
# DEBUG:repartition:	 1: ('CustomBondForce', <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e870> >)
# DEBUG:repartition:	 2: ('HarmonicBondForce', <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x7fd14052e8a0> >)
# DEBUG:repartition:	 3: ('CustomAngleForce', <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd14052e8d0> >)
# DEBUG:repartition:	 4: ('HarmonicAngleForce', <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x7fd14052e900> >)
# DEBUG:repartition:	 5: ('CustomTorsionForce', <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd14052e930> >)
# DEBUG:repartition:	 6: ('PeriodicTorsionForce', <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x7fd14052e960> >)
# DEBUG:repartition:	 7: ('NonbondedForce', <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x7fd14052e990> >)
# DEBUG:repartition:	 8: ('CustomNonbondedForce', <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x7fd14052e9c0> >)
# DEBUG:repartition:	 9: ('CustomBondForce', <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e9f0> >)
# DEBUG:repartition:adding particles and creating selection dictionary
# DEBUG:repartition:hybrid system contains 1564 particles
# DEBUG:repartition:adding 1550 constraints
# DEBUG:repartition:adding virtual sites
# DEBUG:repartition:found a MonteCarloBarostat; adding to 'out_system'
# DEBUG:repartition:adding valence equivalents of CustomBondForce
# DEBUG:repartition:force yanked: <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e870> >
# DEBUG:repartition:found 1 global parameters
# DEBUG:repartition:found 4 per term parameters
# DEBUG:repartition:periodic boundary conditions: False
# DEBUG:repartition:global parameters: [('lambda_bonds', 0.0)]
# DEBUG:repartition:per term parameters: ['length1', 'K1', 'length2', 'K2']
# DEBUG:repartition:queried force (energy) expression: (K/2)*(r-length)^2;K = (1-lambda_bonds)*K1 + lambda_bonds*K2;length = (1-lambda_bonds)*length1 + lambda_bonds*length2;
# DEBUG:repartition:custom force expressions: {'select': 'lambda_select*((K/2)*(r-length)^2);K = (1-lambda_bonds)*K1 + lambda_bonds*K2;length = (1-lambda_bonds)*length1 + lambda_bonds*length2;', 'interselect': 'lambda_interselect*((K/2)*(r-length)^2);K = (1-lambda_bonds)*K1 + lambda_bonds*K2;length = (1-lambda_bonds)*length1 + lambda_bonds*length2;', 'nonselect': 'lambda_nonselect*((K/2)*(r-length)^2);K = (1-lambda_bonds)*K1 + lambda_bonds*K2;length = (1-lambda_bonds)*length1 + lambda_bonds*length2;'}
# DEBUG:repartition:adding force: select --> <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052ea50> >
# DEBUG:repartition:global param: lambda_bonds; value: 0.0
# DEBUG:repartition:adding new global param: lambda_select
# DEBUG:repartition:adding per_term param: length1
# DEBUG:repartition:adding per_term param: K1
# DEBUG:repartition:adding per_term param: length2
# DEBUG:repartition:adding per_term param: K2
# DEBUG:repartition:adding force: interselect --> <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e6c0> >
# DEBUG:repartition:global param: lambda_bonds; value: 0.0
# DEBUG:repartition:adding new global param: lambda_interselect
# DEBUG:repartition:adding per_term param: length1
# DEBUG:repartition:adding per_term param: K1
# DEBUG:repartition:adding per_term param: length2
# DEBUG:repartition:adding per_term param: K2
# DEBUG:repartition:adding force: nonselect --> <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052eae0> >
# DEBUG:repartition:global param: lambda_bonds; value: 0.0
# DEBUG:repartition:adding new global param: lambda_nonselect
# DEBUG:repartition:adding per_term param: length1
# DEBUG:repartition:adding per_term param: K1
# DEBUG:repartition:adding per_term param: length2
# DEBUG:repartition:adding per_term param: K2
# DEBUG:repartition:handling CustomBondForce
# DEBUG:repartition:querying custom valence force: <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e870> >
# DEBUG:repartition:querying standard valence force: <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x7fd14052e8a0> >
# DEBUG:repartition:querying <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7fd14052e870> >
# DEBUG:repartition:is custom: True
# DEBUG:repartition:there are 9 in this force
# DEBUG:repartition:there are 2 particles in each terms
# DEBUG:repartition:particles: [4, 5]
# DEBUG:repartition:query term parameters: [(0.12290000000000001, 476975.9999999999, 0.12290000000000001, 476975.9999999999)]
# DEBUG:repartition:add term input: (4, 5, (0.12290000000000001, 476975.9999999999, 0.12290000000000001, 476975.9999999999))
# DEBUG:repartition:particles: [4, 6]
# DEBUG:repartition:query term parameters: [(0.1335, 410031.99999999994, 0.1335, 410031.99999999994)]
# DEBUG:repartition:add term input: (4, 6, (0.1335, 410031.99999999994, 0.1335, 410031.99999999994))
# DEBUG:repartition:particles: [1, 4]
# DEBUG:repartition:query term parameters: [(0.1522, 265265.6, 0.1522, 265265.6)]
# DEBUG:repartition:add term input: (1, 4, (0.1522, 265265.6, 0.1522, 265265.6))
# DEBUG:repartition:particles: [14, 15]
# DEBUG:repartition:query term parameters: [(0.12290000000000001, 476975.9999999999, 0.12290000000000001, 476975.9999999999)]
# DEBUG:repartition:add term input: (14, 15, (0.12290000000000001, 476975.9999999999, 0.12290000000000001, 476975.9999999999))
# DEBUG:repartition:particles: [14, 16]
# DEBUG:repartition:query term parameters: [(0.1335, 410031.99999999994, 0.1335, 410031.99999999994)]
# DEBUG:repartition:add term input: (14, 16, (0.1335, 410031.99999999994, 0.1335, 410031.99999999994))
# DEBUG:repartition:particles: [8, 10]
# DEBUG:repartition:query term parameters: [(0.1526, 259407.99999999994, 0.1526, 259407.99999999994)]
# DEBUG:repartition:add term input: (8, 10, (0.1526, 259407.99999999994, 0.1526, 259407.99999999994))
# DEBUG:repartition:particles: [8, 14]
# DEBUG:repartition:query term parameters: [(0.1522, 265265.6, 0.1522, 265265.6)]
# DEBUG:repartition:add term input: (8, 14, (0.1522, 265265.6, 0.1522, 265265.6))
# DEBUG:repartition:particles: [6, 8]
# DEBUG:repartition:query term parameters: [(0.1449, 282001.5999999999, 0.1449, 282001.5999999999)]
# DEBUG:repartition:add term input: (6, 8, (0.1449, 282001.5999999999, 0.1449, 282001.5999999999))
# DEBUG:repartition:particles: [16, 18]
# DEBUG:repartition:query term parameters: [(0.1449, 282001.5999999999, 0.1449, 282001.5999999999)]
# DEBUG:repartition:add term input: (16, 18, (0.1449, 282001.5999999999, 0.1449, 282001.5999999999))
# DEBUG:repartition:querying <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x7fd14052e8a0> >
# DEBUG:repartition:is custom: False
# DEBUG:repartition:there are 2 in this force
# DEBUG:repartition:there are 2 particles in each terms
# DEBUG:repartition:particles: [10, 1558]
# DEBUG:repartition:query term parameters: [Quantity(value=0.1526, unit=nanometer), Quantity(value=259407.99999999994, unit=kilojoule/(nanometer**2*mole))]
# DEBUG:repartition:add term input: (10, 1558, [0.1526, 259407.99999999994, 0.1526, 259407.99999999994])
# DEBUG:repartition:particles: [10, 1562]
# DEBUG:repartition:query term parameters: [Quantity(value=0.141, unit=nanometer), Quantity(value=267775.99999999994, unit=kilojoule/(nanometer**2*mole))]
# DEBUG:repartition:add term input: (10, 1562, [0.141, 267775.99999999994, 0.141, 267775.99999999994])
# DEBUG:repartition:adding valence equivalents of CustomAngleForce
# DEBUG:repartition:force yanked: <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd14052e8d0> >
# DEBUG:repartition:found 1 global parameters
# DEBUG:repartition:found 4 per term parameters
# DEBUG:repartition:periodic boundary conditions: False
# DEBUG:repartition:global parameters: [('lambda_angles', 0.0)]
# DEBUG:repartition:per term parameters: ['theta0_1', 'K_1', 'theta0_2', 'K_2']
# DEBUG:repartition:queried force (energy) expression: (K/2)*(theta-theta0)^2;K = (1.0-lambda_angles)*K_1 + lambda_angles*K_2;theta0 = (1.0-lambda_angles)*theta0_1 + lambda_angles*theta0_2;
# DEBUG:repartition:custom force expressions: {'select': 'lambda_select*((K/2)*(theta-theta0)^2);K = (1.0-lambda_angles)*K_1 + lambda_angles*K_2;theta0 = (1.0-lambda_angles)*theta0_1 + lambda_angles*theta0_2;', 'interselect': 'lambda_interselect*((K/2)*(theta-theta0)^2);K = (1.0-lambda_angles)*K_1 + lambda_angles*K_2;theta0 = (1.0-lambda_angles)*theta0_1 + lambda_angles*theta0_2;', 'nonselect': 'lambda_nonselect*((K/2)*(theta-theta0)^2);K = (1.0-lambda_angles)*K_1 + lambda_angles*K_2;theta0 = (1.0-lambda_angles)*theta0_1 + lambda_angles*theta0_2;'}
# DEBUG:repartition:adding force: select --> <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd14070f2d0> >
# DEBUG:repartition:global param: lambda_angles; value: 0.0
# DEBUG:repartition:adding new global param: lambda_select
# DEBUG:repartition:adding per_term param: theta0_1
# DEBUG:repartition:adding per_term param: K_1
# DEBUG:repartition:adding per_term param: theta0_2
# DEBUG:repartition:adding per_term param: K_2
# DEBUG:repartition:adding force: interselect --> <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd175d330c0> >
# DEBUG:repartition:global param: lambda_angles; value: 0.0
# DEBUG:repartition:adding new global param: lambda_interselect
# DEBUG:repartition:adding per_term param: theta0_1
# DEBUG:repartition:adding per_term param: K_1
# DEBUG:repartition:adding per_term param: theta0_2
# DEBUG:repartition:adding per_term param: K_2
# DEBUG:repartition:adding force: nonselect --> <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd175d336f0> >
# DEBUG:repartition:global param: lambda_angles; value: 0.0
# DEBUG:repartition:adding new global param: lambda_nonselect
# DEBUG:repartition:adding per_term param: theta0_1
# DEBUG:repartition:adding per_term param: K_1
# DEBUG:repartition:adding per_term param: theta0_2
# DEBUG:repartition:adding per_term param: K_2
# DEBUG:repartition:handling CustomAngleForce
# DEBUG:repartition:querying custom valence force: <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd14052e8d0> >
# DEBUG:repartition:querying standard valence force: <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x7fd14052e900> >
# DEBUG:repartition:querying <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7fd14052e8d0> >
# DEBUG:repartition:is custom: True
# DEBUG:repartition:there are 30 in this force
# DEBUG:repartition:there are 3 particles in each terms
# DEBUG:repartition:particles: [0, 1, 2]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# DEBUG:repartition:add term input: (0, 1, 2, (1.911135530933791, 292.88, 1.911135530933791, 292.88))
# DEBUG:repartition:particles: [0, 1, 3]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# DEBUG:repartition:add term input: (0, 1, 3, (1.911135530933791, 292.88, 1.911135530933791, 292.88))
# DEBUG:repartition:particles: [0, 1, 4]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (0, 1, 4, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [1, 4, 5]
# DEBUG:repartition:query term parameters: [(2.101376419401173, 669.44, 2.101376419401173, 669.44)]
# DEBUG:repartition:add term input: (1, 4, 5, (2.101376419401173, 669.44, 2.101376419401173, 669.44))
# DEBUG:repartition:particles: [1, 4, 6]
# DEBUG:repartition:query term parameters: [(2.035053907825388, 585.76, 2.035053907825388, 585.76)]
# DEBUG:repartition:add term input: (1, 4, 6, (2.035053907825388, 585.76, 2.035053907825388, 585.76))
# DEBUG:repartition:particles: [2, 1, 3]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# DEBUG:repartition:add term input: (2, 1, 3, (1.911135530933791, 292.88, 1.911135530933791, 292.88))
# DEBUG:repartition:particles: [2, 1, 4]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (2, 1, 4, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [3, 1, 4]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (3, 1, 4, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [4, 6, 7]
# DEBUG:repartition:query term parameters: [(2.0943951023931953, 418.40000000000003, 2.0943951023931953, 418.40000000000003)]
# DEBUG:repartition:add term input: (4, 6, 7, (2.0943951023931953, 418.40000000000003, 2.0943951023931953, 418.40000000000003))
# DEBUG:repartition:particles: [4, 6, 8]
# DEBUG:repartition:query term parameters: [(2.1275563581810877, 418.40000000000003, 2.1275563581810877, 418.40000000000003)]
# DEBUG:repartition:add term input: (4, 6, 8, (2.1275563581810877, 418.40000000000003, 2.1275563581810877, 418.40000000000003))
# DEBUG:repartition:particles: [5, 4, 6]
# DEBUG:repartition:query term parameters: [(2.1450096507010312, 669.44, 2.1450096507010312, 669.44)]
# DEBUG:repartition:add term input: (5, 4, 6, (2.1450096507010312, 669.44, 2.1450096507010312, 669.44))
# DEBUG:repartition:particles: [6, 8, 9]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (6, 8, 9, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [6, 8, 10]
# DEBUG:repartition:query term parameters: [(1.9146261894377796, 669.44, 1.9146261894377796, 669.44)]
# DEBUG:repartition:add term input: (6, 8, 10, (1.9146261894377796, 669.44, 1.9146261894377796, 669.44))
# DEBUG:repartition:particles: [6, 8, 14]
# DEBUG:repartition:query term parameters: [(1.9216075064457567, 527.184, 1.9216075064457567, 527.184)]
# DEBUG:repartition:add term input: (6, 8, 14, (1.9216075064457567, 527.184, 1.9216075064457567, 527.184))
# DEBUG:repartition:particles: [7, 6, 8]
# DEBUG:repartition:query term parameters: [(2.0601866490541068, 418.40000000000003, 2.0601866490541068, 418.40000000000003)]
# DEBUG:repartition:add term input: (7, 6, 8, (2.0601866490541068, 418.40000000000003, 2.0601866490541068, 418.40000000000003))
# DEBUG:repartition:particles: [8, 14, 15]
# DEBUG:repartition:query term parameters: [(2.101376419401173, 669.44, 2.101376419401173, 669.44)]
# DEBUG:repartition:add term input: (8, 14, 15, (2.101376419401173, 669.44, 2.101376419401173, 669.44))
# DEBUG:repartition:particles: [8, 14, 16]
# DEBUG:repartition:query term parameters: [(2.035053907825388, 585.76, 2.035053907825388, 585.76)]
# DEBUG:repartition:add term input: (8, 14, 16, (2.035053907825388, 585.76, 2.035053907825388, 585.76))
# DEBUG:repartition:particles: [9, 8, 10]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (9, 8, 10, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [9, 8, 14]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (9, 8, 14, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [10, 8, 14]
# DEBUG:repartition:query term parameters: [(1.9390607989657, 527.184, 1.9390607989657, 527.184)]
# DEBUG:repartition:add term input: (10, 8, 14, (1.9390607989657, 527.184, 1.9390607989657, 527.184))
# DEBUG:repartition:particles: [14, 16, 17]
# DEBUG:repartition:query term parameters: [(2.0943951023931953, 418.40000000000003, 2.0943951023931953, 418.40000000000003)]
# DEBUG:repartition:add term input: (14, 16, 17, (2.0943951023931953, 418.40000000000003, 2.0943951023931953, 418.40000000000003))
# DEBUG:repartition:particles: [14, 16, 18]
# DEBUG:repartition:query term parameters: [(2.1275563581810877, 418.40000000000003, 2.1275563581810877, 418.40000000000003)]
# DEBUG:repartition:add term input: (14, 16, 18, (2.1275563581810877, 418.40000000000003, 2.1275563581810877, 418.40000000000003))
# DEBUG:repartition:particles: [15, 14, 16]
# DEBUG:repartition:query term parameters: [(2.1450096507010312, 669.44, 2.1450096507010312, 669.44)]
# DEBUG:repartition:add term input: (15, 14, 16, (2.1450096507010312, 669.44, 2.1450096507010312, 669.44))
# DEBUG:repartition:particles: [16, 18, 19]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (16, 18, 19, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [16, 18, 20]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (16, 18, 20, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [16, 18, 21]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# DEBUG:repartition:add term input: (16, 18, 21, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003))
# DEBUG:repartition:particles: [17, 16, 18]
# DEBUG:repartition:query term parameters: [(2.0601866490541068, 418.40000000000003, 2.0601866490541068, 418.40000000000003)]
# DEBUG:repartition:add term input: (17, 16, 18, (2.0601866490541068, 418.40000000000003, 2.0601866490541068, 418.40000000000003))
# DEBUG:repartition:particles: [19, 18, 20]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# DEBUG:repartition:add term input: (19, 18, 20, (1.911135530933791, 292.88, 1.911135530933791, 292.88))
# DEBUG:repartition:particles: [19, 18, 21]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# DEBUG:repartition:add term input: (19, 18, 21, (1.911135530933791, 292.88, 1.911135530933791, 292.88))
# DEBUG:repartition:particles: [20, 18, 21]
# DEBUG:repartition:query term parameters: [(1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# DEBUG:repartition:add term input: (20, 18, 21, (1.911135530933791, 292.88, 1.911135530933791, 292.88))
# DEBUG:repartition:querying <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x7fd14052e900> >
# DEBUG:repartition:is custom: False
# DEBUG:repartition:there are 19 in this force
# DEBUG:repartition:there are 3 particles in each terms
# DEBUG:repartition:particles: [8, 10, 11]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (8, 10, 11, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [8, 10, 12]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (8, 10, 12, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [8, 10, 13]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (8, 10, 13, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [11, 10, 12]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=292.88, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (11, 10, 12, [1.911135530933791, 292.88, 1.911135530933791, 292.88])
# DEBUG:repartition:particles: [11, 10, 13]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=292.88, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (11, 10, 13, [1.911135530933791, 292.88, 1.911135530933791, 292.88])
# DEBUG:repartition:particles: [12, 10, 13]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=292.88, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (12, 10, 13, [1.911135530933791, 292.88, 1.911135530933791, 292.88])
# DEBUG:repartition:particles: [8, 10, 1557]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (8, 10, 1557, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [8, 10, 1558]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=334.72, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (8, 10, 1558, [1.911135530933791, 334.72, 1.911135530933791, 334.72])
# DEBUG:repartition:particles: [8, 10, 1562]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (8, 10, 1562, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [10, 1558, 1559]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (10, 1558, 1559, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [10, 1558, 1560]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (10, 1558, 1560, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [10, 1558, 1561]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (10, 1558, 1561, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [10, 1562, 1563]
# DEBUG:repartition:query term parameters: [Quantity(value=1.8936822384138476, unit=radian), Quantity(value=460.24, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (10, 1562, 1563, [1.8936822384138476, 460.24, 1.8936822384138476, 460.24])
# DEBUG:repartition:particles: [1557, 10, 1558]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (1557, 10, 1558, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [1557, 10, 1562]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (1557, 10, 1562, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [1558, 10, 1562]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=418.40000000000003, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (1558, 10, 1562, [1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003])
# DEBUG:repartition:particles: [1559, 1558, 1560]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=292.88, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (1559, 1558, 1560, [1.911135530933791, 292.88, 1.911135530933791, 292.88])
# DEBUG:repartition:particles: [1559, 1558, 1561]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=292.88, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (1559, 1558, 1561, [1.911135530933791, 292.88, 1.911135530933791, 292.88])
# DEBUG:repartition:particles: [1560, 1558, 1561]
# DEBUG:repartition:query term parameters: [Quantity(value=1.911135530933791, unit=radian), Quantity(value=292.88, unit=kilojoule/(mole*radian**2))]
# DEBUG:repartition:add term input: (1560, 1558, 1561, [1.911135530933791, 292.88, 1.911135530933791, 292.88])
# DEBUG:repartition:adding valence equivalents of CustomTorsionForce
# DEBUG:repartition:force yanked: <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd14052e930> >
# DEBUG:repartition:found 1 global parameters
# DEBUG:repartition:found 6 per term parameters
# DEBUG:repartition:periodic boundary conditions: False
# DEBUG:repartition:global parameters: [('lambda_torsions', 0.0)]
# DEBUG:repartition:per term parameters: ['periodicity1', 'phase1', 'K1', 'periodicity2', 'phase2', 'K2']
# DEBUG:repartition:queried force (energy) expression: (1-lambda_torsions)*U1 + lambda_torsions*U2;U1 = K1*(1+cos(periodicity1*theta-phase1));U2 = K2*(1+cos(periodicity2*theta-phase2));
# DEBUG:repartition:custom force expressions: {'select': 'lambda_select*((1-lambda_torsions)*U1 + lambda_torsions*U2);U1 = K1*(1+cos(periodicity1*theta-phase1));U2 = K2*(1+cos(periodicity2*theta-phase2));', 'interselect': 'lambda_interselect*((1-lambda_torsions)*U1 + lambda_torsions*U2);U1 = K1*(1+cos(periodicity1*theta-phase1));U2 = K2*(1+cos(periodicity2*theta-phase2));', 'nonselect': 'lambda_nonselect*((1-lambda_torsions)*U1 + lambda_torsions*U2);U1 = K1*(1+cos(periodicity1*theta-phase1));U2 = K2*(1+cos(periodicity2*theta-phase2));'}
# DEBUG:repartition:adding force: select --> <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd19d2bf030> >
# DEBUG:repartition:global param: lambda_torsions; value: 0.0
# DEBUG:repartition:adding new global param: lambda_select
# DEBUG:repartition:adding per_term param: periodicity1
# DEBUG:repartition:adding per_term param: phase1
# DEBUG:repartition:adding per_term param: K1
# DEBUG:repartition:adding per_term param: periodicity2
# DEBUG:repartition:adding per_term param: phase2
# DEBUG:repartition:adding per_term param: K2
# DEBUG:repartition:adding force: interselect --> <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd14052eb40> >
# DEBUG:repartition:global param: lambda_torsions; value: 0.0
# DEBUG:repartition:adding new global param: lambda_interselect
# DEBUG:repartition:adding per_term param: periodicity1
# DEBUG:repartition:adding per_term param: phase1
# DEBUG:repartition:adding per_term param: K1
# DEBUG:repartition:adding per_term param: periodicity2
# DEBUG:repartition:adding per_term param: phase2
# DEBUG:repartition:adding per_term param: K2
# DEBUG:repartition:adding force: nonselect --> <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd14052eba0> >
# DEBUG:repartition:global param: lambda_torsions; value: 0.0
# DEBUG:repartition:adding new global param: lambda_nonselect
# DEBUG:repartition:adding per_term param: periodicity1
# DEBUG:repartition:adding per_term param: phase1
# DEBUG:repartition:adding per_term param: K1
# DEBUG:repartition:adding per_term param: periodicity2
# DEBUG:repartition:adding per_term param: phase2
# DEBUG:repartition:adding per_term param: K2
# DEBUG:repartition:handling CustomTorsionForce
# DEBUG:repartition:querying custom valence force: <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd14052e930> >
# DEBUG:repartition:querying standard valence force: <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x7fd14052e960> >
# DEBUG:repartition:querying <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7fd14052e930> >
# DEBUG:repartition:is custom: True
# DEBUG:repartition:there are 0 in this force
# DEBUG:repartition:there are 4 particles in each terms
# DEBUG:repartition:querying <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x7fd14052e960> >
# DEBUG:repartition:is custom: False
# DEBUG:repartition:there are 81 in this force
# DEBUG:repartition:there are 4 particles in each terms
# DEBUG:repartition:particles: [6, 8, 10, 11]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 11, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [6, 8, 10, 12]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 12, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [6, 8, 10, 13]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 13, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [9, 8, 10, 11]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 10, 11, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [9, 8, 10, 12]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 10, 12, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [9, 8, 10, 13]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 10, 13, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [11, 10, 8, 14]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (11, 10, 8, 14, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [12, 10, 8, 14]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (12, 10, 8, 14, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [13, 10, 8, 14]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (13, 10, 8, 14, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [0, 1, 4, 5]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=3.3472000000000004, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (0, 1, 4, 5, [1, 0.0, 3.3472000000000004, 1, 0.0, 3.3472000000000004])
# DEBUG:repartition:particles: [0, 1, 4, 5]
# DEBUG:repartition:query term parameters: [3, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.33472, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (0, 1, 4, 5, [3, 3.141592653589793, 0.33472, 3, 3.141592653589793, 0.33472])
# DEBUG:repartition:particles: [1, 4, 6, 7]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1, 4, 6, 7, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [1, 4, 6, 8]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1, 4, 6, 8, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [2, 1, 4, 5]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=3.3472000000000004, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (2, 1, 4, 5, [1, 0.0, 3.3472000000000004, 1, 0.0, 3.3472000000000004])
# DEBUG:repartition:particles: [2, 1, 4, 5]
# DEBUG:repartition:query term parameters: [3, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.33472, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (2, 1, 4, 5, [3, 3.141592653589793, 0.33472, 3, 3.141592653589793, 0.33472])
# DEBUG:repartition:particles: [3, 1, 4, 5]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=3.3472000000000004, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (3, 1, 4, 5, [1, 0.0, 3.3472000000000004, 1, 0.0, 3.3472000000000004])
# DEBUG:repartition:particles: [3, 1, 4, 5]
# DEBUG:repartition:query term parameters: [3, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.33472, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (3, 1, 4, 5, [3, 3.141592653589793, 0.33472, 3, 3.141592653589793, 0.33472])
# DEBUG:repartition:particles: [4, 6, 8, 10]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=3.3472000000000004, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (4, 6, 8, 10, [3, 0.0, 3.3472000000000004, 3, 0.0, 3.3472000000000004])
# DEBUG:repartition:particles: [4, 6, 8, 10]
# DEBUG:repartition:query term parameters: [2, Quantity(value=0.0, unit=radian), Quantity(value=7.5312, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (4, 6, 8, 10, [2, 0.0, 7.5312, 2, 0.0, 7.5312])
# DEBUG:repartition:particles: [4, 6, 8, 10]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=8.368, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (4, 6, 8, 10, [1, 0.0, 8.368, 1, 0.0, 8.368])
# DEBUG:repartition:particles: [4, 6, 8, 14]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=1.75728, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (4, 6, 8, 14, [3, 0.0, 1.75728, 3, 0.0, 1.75728])
# DEBUG:repartition:particles: [4, 6, 8, 14]
# DEBUG:repartition:query term parameters: [2, Quantity(value=0.0, unit=radian), Quantity(value=1.12968, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (4, 6, 8, 14, [2, 0.0, 1.12968, 2, 0.0, 1.12968])
# DEBUG:repartition:particles: [5, 4, 6, 7]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (5, 4, 6, 7, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [5, 4, 6, 7]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=8.368, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (5, 4, 6, 7, [1, 0.0, 8.368, 1, 0.0, 8.368])
# DEBUG:repartition:particles: [5, 4, 6, 8]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (5, 4, 6, 8, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [6, 8, 10, 1557]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1557, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [6, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [4, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.004184, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1558, [4, 3.141592653589793, 0.004184, 4, 3.141592653589793, 0.004184])
# DEBUG:repartition:particles: [6, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.619232, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1558, [3, 0.0, 0.619232, 3, 0.0, 0.619232])
# DEBUG:repartition:particles: [6, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.903744, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1558, [2, 3.141592653589793, 0.903744, 2, 3.141592653589793, 0.903744])
# DEBUG:repartition:particles: [6, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=1.4100080000000002, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1558, [1, 0.0, 1.4100080000000002, 1, 0.0, 1.4100080000000002])
# DEBUG:repartition:particles: [6, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [4, Quantity(value=0.0, unit=radian), Quantity(value=0.39748, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1562, [4, 0.0, 0.39748, 4, 0.0, 0.39748])
# DEBUG:repartition:particles: [6, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=1.31796, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1562, [3, 0.0, 1.31796, 3, 0.0, 1.31796])
# DEBUG:repartition:particles: [6, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [2, Quantity(value=0.0, unit=radian), Quantity(value=0.025104, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1562, [2, 0.0, 0.025104, 2, 0.0, 0.025104])
# DEBUG:repartition:particles: [6, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=2.8200160000000003, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 10, 1562, [1, 0.0, 2.8200160000000003, 1, 0.0, 2.8200160000000003])
# DEBUG:repartition:particles: [6, 8, 14, 16]
# DEBUG:repartition:query term parameters: [3, Quantity(value=3.141592653589793, unit=radian), Quantity(value=2.3012, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 14, 16, [3, 3.141592653589793, 2.3012, 3, 3.141592653589793, 2.3012])
# DEBUG:repartition:particles: [6, 8, 14, 16]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=6.610720000000001, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 14, 16, [2, 3.141592653589793, 6.610720000000001, 2, 3.141592653589793, 6.610720000000001])
# DEBUG:repartition:particles: [6, 8, 14, 16]
# DEBUG:repartition:query term parameters: [1, Quantity(value=3.141592653589793, unit=radian), Quantity(value=1.8828, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (6, 8, 14, 16, [1, 3.141592653589793, 1.8828, 1, 3.141592653589793, 1.8828])
# DEBUG:repartition:particles: [8, 10, 1558, 1559]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.66944, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 10, 1558, 1559, [3, 0.0, 0.66944, 3, 0.0, 0.66944])
# DEBUG:repartition:particles: [8, 10, 1558, 1560]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.66944, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 10, 1558, 1560, [3, 0.0, 0.66944, 3, 0.0, 0.66944])
# DEBUG:repartition:particles: [8, 10, 1558, 1561]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.66944, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 10, 1558, 1561, [3, 0.0, 0.66944, 3, 0.0, 0.66944])
# DEBUG:repartition:particles: [8, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [4, Quantity(value=0.0, unit=radian), Quantity(value=0.054392, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 10, 1562, 1563, [4, 0.0, 0.054392, 4, 0.0, 0.054392])
# DEBUG:repartition:particles: [8, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.987424, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 10, 1562, 1563, [3, 0.0, 0.987424, 3, 0.0, 0.987424])
# DEBUG:repartition:particles: [8, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [2, Quantity(value=0.0, unit=radian), Quantity(value=1.050184, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 10, 1562, 1563, [2, 0.0, 1.050184, 2, 0.0, 1.050184])
# DEBUG:repartition:particles: [8, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [1, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.025104, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 10, 1562, 1563, [1, 3.141592653589793, 0.025104, 1, 3.141592653589793, 0.025104])
# DEBUG:repartition:particles: [8, 14, 16, 17]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 14, 16, 17, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [8, 14, 16, 18]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 14, 16, 18, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [9, 8, 10, 1557]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 10, 1557, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [9, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 10, 1558, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [9, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=1.046, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 10, 1562, [1, 0.0, 1.046, 1, 0.0, 1.046])
# DEBUG:repartition:particles: [9, 8, 14, 15]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=3.3472000000000004, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 14, 15, [1, 0.0, 3.3472000000000004, 1, 0.0, 3.3472000000000004])
# DEBUG:repartition:particles: [9, 8, 14, 15]
# DEBUG:repartition:query term parameters: [3, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.33472, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (9, 8, 14, 15, [3, 3.141592653589793, 0.33472, 3, 3.141592653589793, 0.33472])
# DEBUG:repartition:particles: [10, 8, 14, 16]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=1.6736000000000002, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (10, 8, 14, 16, [3, 0.0, 1.6736000000000002, 3, 0.0, 1.6736000000000002])
# DEBUG:repartition:particles: [10, 8, 14, 16]
# DEBUG:repartition:query term parameters: [2, Quantity(value=0.0, unit=radian), Quantity(value=0.8368000000000001, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (10, 8, 14, 16, [2, 0.0, 0.8368000000000001, 2, 0.0, 0.8368000000000001])
# DEBUG:repartition:particles: [10, 8, 14, 16]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=0.8368000000000001, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (10, 8, 14, 16, [1, 0.0, 0.8368000000000001, 1, 0.0, 0.8368000000000001])
# DEBUG:repartition:particles: [14, 8, 10, 1557]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1557, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [14, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [4, Quantity(value=0.0, unit=radian), Quantity(value=0.468608, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1558, [4, 0.0, 0.468608, 4, 0.0, 0.468608])
# DEBUG:repartition:particles: [14, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.619232, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1558, [3, 0.0, 0.619232, 3, 0.0, 0.619232])
# DEBUG:repartition:particles: [14, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=1.209176, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1558, [2, 3.141592653589793, 1.209176, 2, 3.141592653589793, 1.209176])
# DEBUG:repartition:particles: [14, 8, 10, 1558]
# DEBUG:repartition:query term parameters: [1, Quantity(value=3.141592653589793, unit=radian), Quantity(value=1.6987040000000002, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1558, [1, 3.141592653589793, 1.6987040000000002, 1, 3.141592653589793, 1.6987040000000002])
# DEBUG:repartition:particles: [14, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [4, Quantity(value=0.0, unit=radian), Quantity(value=0.6527040000000001, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1562, [4, 0.0, 0.6527040000000001, 4, 0.0, 0.6527040000000001])
# DEBUG:repartition:particles: [14, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=1.31796, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1562, [3, 0.0, 1.31796, 3, 0.0, 1.31796])
# DEBUG:repartition:particles: [14, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.497896, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1562, [2, 3.141592653589793, 0.497896, 2, 3.141592653589793, 0.497896])
# DEBUG:repartition:particles: [14, 8, 10, 1562]
# DEBUG:repartition:query term parameters: [1, Quantity(value=3.141592653589793, unit=radian), Quantity(value=2.916248, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 8, 10, 1562, [1, 3.141592653589793, 2.916248, 1, 3.141592653589793, 2.916248])
# DEBUG:repartition:particles: [15, 14, 16, 17]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (15, 14, 16, 17, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [15, 14, 16, 17]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=8.368, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (15, 14, 16, 17, [1, 0.0, 8.368, 1, 0.0, 8.368])
# DEBUG:repartition:particles: [15, 14, 16, 18]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=10.46, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (15, 14, 16, 18, [2, 3.141592653589793, 10.46, 2, 3.141592653589793, 10.46])
# DEBUG:repartition:particles: [1557, 10, 1558, 1559]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1557, 10, 1558, 1559, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [1557, 10, 1558, 1560]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1557, 10, 1558, 1560, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [1557, 10, 1558, 1561]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6508444444444444, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1557, 10, 1558, 1561, [3, 0.0, 0.6508444444444444, 3, 0.0, 0.6508444444444444])
# DEBUG:repartition:particles: [1557, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.6973333333333334, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1557, 10, 1562, 1563, [3, 0.0, 0.6973333333333334, 3, 0.0, 0.6973333333333334])
# DEBUG:repartition:particles: [1558, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [4, Quantity(value=0.0, unit=radian), Quantity(value=0.200832, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1558, 10, 1562, 1563, [4, 0.0, 0.200832, 4, 0.0, 0.200832])
# DEBUG:repartition:particles: [1558, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [3, Quantity(value=0.0, unit=radian), Quantity(value=0.987424, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1558, 10, 1562, 1563, [3, 0.0, 0.987424, 3, 0.0, 0.987424])
# DEBUG:repartition:particles: [1558, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=0.330536, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1558, 10, 1562, 1563, [2, 3.141592653589793, 0.330536, 2, 3.141592653589793, 0.330536])
# DEBUG:repartition:particles: [1558, 10, 1562, 1563]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=2.690312, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1558, 10, 1562, 1563, [1, 0.0, 2.690312, 1, 0.0, 2.690312])
# DEBUG:repartition:particles: [1559, 1558, 10, 1562]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=1.046, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1559, 1558, 10, 1562, [1, 0.0, 1.046, 1, 0.0, 1.046])
# DEBUG:repartition:particles: [1560, 1558, 10, 1562]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=1.046, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1560, 1558, 10, 1562, [1, 0.0, 1.046, 1, 0.0, 1.046])
# DEBUG:repartition:particles: [1561, 1558, 10, 1562]
# DEBUG:repartition:query term parameters: [1, Quantity(value=0.0, unit=radian), Quantity(value=1.046, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1561, 1558, 10, 1562, [1, 0.0, 1.046, 1, 0.0, 1.046])
# DEBUG:repartition:particles: [1, 6, 4, 5]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=43.932, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (1, 6, 4, 5, [2, 3.141592653589793, 43.932, 2, 3.141592653589793, 43.932])
# DEBUG:repartition:particles: [4, 8, 6, 7]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=4.6024, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (4, 8, 6, 7, [2, 3.141592653589793, 4.6024, 2, 3.141592653589793, 4.6024])
# DEBUG:repartition:particles: [8, 16, 14, 15]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=43.932, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (8, 16, 14, 15, [2, 3.141592653589793, 43.932, 2, 3.141592653589793, 43.932])
# DEBUG:repartition:particles: [14, 18, 16, 17]
# DEBUG:repartition:query term parameters: [2, Quantity(value=3.141592653589793, unit=radian), Quantity(value=4.6024, unit=kilojoule/mole)]
# DEBUG:repartition:add term input: (14, 18, 16, 17, [2, 3.141592653589793, 4.6024, 2, 3.141592653589793, 4.6024])
# DEBUG:repartition:handling nonbonded_forces
# DEBUG:repartition:pulled standard nonbonded (electrostatic + env) force from hybrid system
# DEBUG:repartition:pulled custom nonbonded (steric + env) force from hybrid system
# DEBUG:repartition:adding global parameters to customnonbonded force
# DEBUG:repartition:adding per particle parameters to customnonbonded force
# DEBUG:repartition:handling nonbonded parameters...
# DEBUG:repartition:found nonbondedmethod: 4
# DEBUG:repartition:failed to query/set long range correction of <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x7fd14052e990> >
# DEBUG:repartition:found nonbondedmethod: 2
# DEBUG:repartition:failed to query/set reaction field dielectric of <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x7fd14052e9c0> >
# DEBUG:repartition:failed to query/set PME and Ewald parameters of <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x7fd14052e9c0> >
# DEBUG:repartition:failed to query/set dispersion of <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x7fd14052e9c0> >
# DEBUG:repartition:there are 1693 standard nonbonded exceptions
# DEBUG:repartition:there are 160 standard nonbonded offsets
# DEBUG:repartition:there are 29 standard nonbonded exception offsets
# DEBUG:repartition:iterating over particles
# DEBUG:repartition:adding interaction group...

# %% [markdown]
# can we check the valence terms for matching?

# %%
from openmmtools.states import CompoundThermodynamicState, SamplerState, ThermodynamicState
from perses.annihilation.lambda_protocol import RelativeAlchemicalState, LambdaProtocol
from openmmtools.integrators import LangevinIntegrator
from simtk import unit
from openmmtools import cache
temp = 300 * unit.kelvin
from perses.tests.utils import compute_potential_components
import copy
beta = 1/(kB * temp)
from perses.dispersed.feptasks import minimize

# %%
from coddiwomple.openmm.states import OpenMMPDFState
thermostate = OpenMMPDFState(htf._hybrid_system, alchemical_composability=RelativeAlchemicalState)
particle_state = SamplerState(htf._hybrid_positions, box_vectors = htf._hybrid_system.getDefaultPeriodicBoxVectors())
minimize(thermostate, particle_state)
thermostate.reduced_potential(particle_state)
print(compute_potential_components(thermostate._internal_context, beta=beta))
# Out:
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# [('CustomBondForce', 1.1835315323907345), ('HarmonicBondForce', 0.10409370406068914), ('CustomAngleForce', 2.1769512995479943), ('HarmonicAngleForce', 2.9833644466207057), ('CustomTorsionForce', 0.0), ('PeriodicTorsionForce', 27.311004565323927), ('NonbondedForce', -9828.27877524575), ('CustomNonbondedForce', -13.478863019639542), ('CustomBondForce', 0.0), ('AndersenThermostat', 0.0), ('MonteCarloBarostat', 0.0)]

# %%
rep_thermostate = OpenMMPDFState(repartitioned_system, alchemical_composability=RelativeAlchemicalState)
print(compute_potential_components(rep_thermostate._internal_context, beta=beta))
# Out:
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# [('CustomBondForce', 14144.203279073583), ('CustomBondForce', 0.0), ('CustomBondForce', 0.0), ('CustomAngleForce', nan), ('CustomAngleForce', 0.0), ('CustomAngleForce', 0.0), ('CustomTorsionForce', 188.62416349845137), ('CustomTorsionForce', 0.0), ('CustomTorsionForce', 0.0), ('CustomBondForce', 0.0), ('NonbondedForce', nan), ('CustomNonbondedForce', nan), ('AndersenThermostat', 0.0), ('MonteCarloBarostat', 0.0)]

# %%
custom_angle_force = repartitioned_system.getForce(4)

# %%
custom_angle_force.getEnergyFunction()
# Out:
# 'lambda_select*((K/2)*(theta-theta0)^2);K = (1.0-lambda_angles)*K_1 + lambda_angles*K_2;theta0 = (1.0-lambda_angles)*theta0_1 + lambda_angles*theta0_2;'

# %%
num_angles = custom_angle_force.getNumAngles()
num_per_angle_params = custom_angle_force.getNumPerAngleParameters()
for angle_idx in range(num_angles):
    print(custom_angle_force.getAngleParameters(angle_idx))
# Out:
# [0, 1, 2, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [0, 1, 3, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [0, 1, 4, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [1, 4, 5, (2.101376419401173, 669.44, 2.101376419401173, 669.44)]
# [1, 4, 6, (2.035053907825388, 585.76, 2.035053907825388, 585.76)]
# [2, 1, 3, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [2, 1, 4, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [3, 1, 4, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [4, 6, 7, (2.0943951023931953, 418.40000000000003, 2.0943951023931953, 418.40000000000003)]
# [4, 6, 8, (2.1275563581810877, 418.40000000000003, 2.1275563581810877, 418.40000000000003)]
# [5, 4, 6, (2.1450096507010312, 669.44, 2.1450096507010312, 669.44)]
# [6, 8, 9, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [6, 8, 10, (1.9146261894377796, 669.44, 1.9146261894377796, 669.44)]
# [6, 8, 14, (1.9216075064457567, 527.184, 1.9216075064457567, 527.184)]
# [7, 6, 8, (2.0601866490541068, 418.40000000000003, 2.0601866490541068, 418.40000000000003)]
# [8, 14, 15, (2.101376419401173, 669.44, 2.101376419401173, 669.44)]
# [8, 14, 16, (2.035053907825388, 585.76, 2.035053907825388, 585.76)]
# [9, 8, 10, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [9, 8, 14, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [10, 8, 14, (1.9390607989657, 527.184, 1.9390607989657, 527.184)]
# [14, 16, 17, (2.0943951023931953, 418.40000000000003, 2.0943951023931953, 418.40000000000003)]
# [14, 16, 18, (2.1275563581810877, 418.40000000000003, 2.1275563581810877, 418.40000000000003)]
# [15, 14, 16, (2.1450096507010312, 669.44, 2.1450096507010312, 669.44)]
# [16, 18, 19, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [16, 18, 20, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [16, 18, 21, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [17, 16, 18, (2.0601866490541068, 418.40000000000003, 2.0601866490541068, 418.40000000000003)]
# [19, 18, 20, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [19, 18, 21, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [20, 18, 21, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [8, 10, 11, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [8, 10, 12, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [8, 10, 13, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [11, 10, 12, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [11, 10, 13, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [12, 10, 13, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [8, 10, 1557, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [8, 10, 1558, (1.911135530933791, 334.72, 1.911135530933791, 334.72)]
# [8, 10, 1562, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [10, 1558, 1559, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [10, 1558, 1560, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [10, 1558, 1561, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [10, 1562, 1563, (1.8936822384138476, 460.24, 1.8936822384138476, 460.24)]
# [1557, 10, 1558, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [1557, 10, 1562, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [1558, 10, 1562, (1.911135530933791, 418.40000000000003, 1.911135530933791, 418.40000000000003)]
# [1559, 1558, 1560, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [1559, 1558, 1561, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]
# [1560, 1558, 1561, (1.911135530933791, 292.88, 1.911135530933791, 292.88)]

# %%
for angle_param_name in range(num_per_angle_params):

# %%
zero_params = thermostate.get_parameters()
one_params = {key:1.0 for key in zero_params.keys()}
thermostate.set_parameters(one_params)
print(thermostate.reduced_potential(particle_state))
print(compute_potential_components(thermostate._internal_context, beta=beta))
