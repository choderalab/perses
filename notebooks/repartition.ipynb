# %% [markdown]
# ## Attempt to make a factory that is REST and BLUES compatible

# %% [markdown]
# we need to be able to make a factory that will take a hybrid system and generate another hybrid system with different alchemical regions (not unlike the openmmtools `AlchemicalRegion`) but something that is specific to perses...

# %% [markdown]
# ### Generate a test system to play with...

# %%
from pkg_resources import resource_filename
from simtk.openmm import app
import mdtraj as md
from perses.tests.test_topology_proposal import generate_atp, generate_dipeptide_top_pos_sys
from openmmtools.constants import kB
from simtk import unit, openmm
# Out:
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=6)
#            2	LOAD_GLOBAL(arg=0, lineno=6)
#            4	LOAD_METHOD(arg=1, lineno=6)
#            6	LOAD_CONST(arg=1, lineno=6)
#            8	CALL_METHOD(arg=1, lineno=6)
#           10	STORE_FAST(arg=2, lineno=6)
#           12	LOAD_FAST(arg=0, lineno=7)
#           14	LOAD_CONST(arg=2, lineno=7)
#           16	BINARY_SUBSCR(arg=None, lineno=7)
#           18	LOAD_FAST(arg=1, lineno=7)
#           20	LOAD_CONST(arg=3, lineno=7)
#           22	BINARY_SUBSCR(arg=None, lineno=7)
#           24	BINARY_MULTIPLY(arg=None, lineno=7)
#           26	LOAD_FAST(arg=0, lineno=7)
#           28	LOAD_CONST(arg=3, lineno=7)
#           30	BINARY_SUBSCR(arg=None, lineno=7)
#           32	LOAD_FAST(arg=1, lineno=7)
#           34	LOAD_CONST(arg=2, lineno=7)
#           36	BINARY_SUBSCR(arg=None, lineno=7)
#           38	BINARY_MULTIPLY(arg=None, lineno=7)
#           40	BINARY_SUBTRACT(arg=None, lineno=7)
#           42	LOAD_FAST(arg=2, lineno=7)
#           44	LOAD_CONST(arg=4, lineno=7)
#           46	STORE_SUBSCR(arg=None, lineno=7)
#           48	LOAD_FAST(arg=0, lineno=8)
#           50	LOAD_CONST(arg=3, lineno=8)
#           52	BINARY_SUBSCR(arg=None, lineno=8)
#           54	LOAD_FAST(arg=1, lineno=8)
#           56	LOAD_CONST(arg=4, lineno=8)
#           58	BINARY_SUBSCR(arg=None, lineno=8)
#           60	BINARY_MULTIPLY(arg=None, lineno=8)
#           62	LOAD_FAST(arg=0, lineno=8)
#           64	LOAD_CONST(arg=4, lineno=8)
#           66	BINARY_SUBSCR(arg=None, lineno=8)
#           68	LOAD_FAST(arg=1, lineno=8)
#           70	LOAD_CONST(arg=3, lineno=8)
#           72	BINARY_SUBSCR(arg=None, lineno=8)
#           74	BINARY_MULTIPLY(arg=None, lineno=8)
#           76	BINARY_SUBTRACT(arg=None, lineno=8)
#           78	LOAD_FAST(arg=2, lineno=8)
#           80	LOAD_CONST(arg=2, lineno=8)
#           82	STORE_SUBSCR(arg=None, lineno=8)
#           84	LOAD_FAST(arg=0, lineno=9)
#           86	LOAD_CONST(arg=4, lineno=9)
#           88	BINARY_SUBSCR(arg=None, lineno=9)
#           90	LOAD_FAST(arg=1, lineno=9)
#           92	LOAD_CONST(arg=2, lineno=9)
#           94	BINARY_SUBSCR(arg=None, lineno=9)
#           96	BINARY_MULTIPLY(arg=None, lineno=9)
#           98	LOAD_FAST(arg=0, lineno=9)
#          100	LOAD_CONST(arg=2, lineno=9)
#          102	BINARY_SUBSCR(arg=None, lineno=9)
#          104	LOAD_FAST(arg=1, lineno=9)
#          106	LOAD_CONST(arg=4, lineno=9)
#          108	BINARY_SUBSCR(arg=None, lineno=9)
#          110	BINARY_MULTIPLY(arg=None, lineno=9)
#          112	BINARY_SUBTRACT(arg=None, lineno=9)
#          114	LOAD_FAST(arg=2, lineno=9)
#          116	LOAD_CONST(arg=3, lineno=9)
#          118	STORE_SUBSCR(arg=None, lineno=9)
#          120	LOAD_FAST(arg=2, lineno=10)
#          122	RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=CALL_METHOD(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$const6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=STORE_FAST(arg=2, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$8call_method.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$a12.4', '$const14.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$b18.7', '$const20.8']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$16binary_subscr.6', '$22binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_FAST(arg=0, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=LOAD_CONST(arg=3, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$a26.11', '$const28.12']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=1, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=BINARY_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$b32.14', '$const34.15']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=BINARY_MULTIPLY(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$30binary_subscr.13', '$36binary_subscr.16']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=BINARY_SUBTRACT(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$24binary_multiply.10', '$38binary_multiply.17']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=LOAD_FAST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=LOAD_CONST(arg=4, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19']
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=STORE_SUBSCR(arg=None, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$40binary_subtract.18', '$c42.19', '$const44.20']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=50, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$a48.21', '$const50.22']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$b54.24', '$const56.25']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$52binary_subscr.23', '$58binary_subscr.26']
# DEBUG:numba.core.byteflow:dispatch pc=62, inst=LOAD_FAST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=LOAD_CONST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$a62.28', '$const64.29']
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=LOAD_FAST(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30']
# DEBUG:numba.core.byteflow:dispatch pc=70, inst=LOAD_CONST(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=BINARY_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$b68.31', '$const70.32']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=BINARY_MULTIPLY(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$66binary_subscr.30', '$72binary_subscr.33']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=BINARY_SUBTRACT(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$60binary_multiply.27', '$74binary_multiply.34']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=LOAD_FAST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35']
# DEBUG:numba.core.byteflow:dispatch pc=80, inst=LOAD_CONST(arg=2, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36']
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=STORE_SUBSCR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$76binary_subtract.35', '$c78.36', '$const80.37']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$a84.38', '$const86.39']
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$b90.41', '$const92.42']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$88binary_subscr.40', '$94binary_subscr.43']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=LOAD_CONST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$a98.45', '$const100.46']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=LOAD_FAST(arg=1, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=LOAD_CONST(arg=4, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$b104.48', '$const106.49']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=BINARY_MULTIPLY(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$102binary_subscr.47', '$108binary_subscr.50']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=BINARY_SUBTRACT(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$96binary_multiply.44', '$110binary_multiply.51']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=2, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=LOAD_CONST(arg=3, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=STORE_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$112binary_subtract.52', '$c114.53', '$const116.54']
# DEBUG:numba.core.byteflow:dispatch pc=120, inst=LOAD_FAST(arg=2, lineno=10)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=RETURN_VALUE(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$c120.55']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$const6.2'}), (8, {'func': '$4load_method.1', 'args': ['$const6.2'], 'res': '$8call_method.3'}), (10, {'value': '$8call_method.3'}), (12, {'res': '$a12.4'}), (14, {'res': '$const14.5'}), (16, {'index': '$const14.5', 'target': '$a12.4', 'res': '$16binary_subscr.6'}), (18, {'res': '$b18.7'}), (20, {'res': '$const20.8'}), (22, {'index': '$const20.8', 'target': '$b18.7', 'res': '$22binary_subscr.9'}), (24, {'lhs': '$16binary_subscr.6', 'rhs': '$22binary_subscr.9', 'res': '$24binary_multiply.10'}), (26, {'res': '$a26.11'}), (28, {'res': '$const28.12'}), (30, {'index': '$const28.12', 'target': '$a26.11', 'res': '$30binary_subscr.13'}), (32, {'res': '$b32.14'}), (34, {'res': '$const34.15'}), (36, {'index': '$const34.15', 'target': '$b32.14', 'res': '$36binary_subscr.16'}), (38, {'lhs': '$30binary_subscr.13', 'rhs': '$36binary_subscr.16', 'res': '$38binary_multiply.17'}), (40, {'lhs': '$24binary_multiply.10', 'rhs': '$38binary_multiply.17', 'res': '$40binary_subtract.18'}), (42, {'res': '$c42.19'}), (44, {'res': '$const44.20'}), (46, {'target': '$c42.19', 'index': '$const44.20', 'value': '$40binary_subtract.18'}), (48, {'res': '$a48.21'}), (50, {'res': '$const50.22'}), (52, {'index': '$const50.22', 'target': '$a48.21', 'res': '$52binary_subscr.23'}), (54, {'res': '$b54.24'}), (56, {'res': '$const56.25'}), (58, {'index': '$const56.25', 'target': '$b54.24', 'res': '$58binary_subscr.26'}), (60, {'lhs': '$52binary_subscr.23', 'rhs': '$58binary_subscr.26', 'res': '$60binary_multiply.27'}), (62, {'res': '$a62.28'}), (64, {'res': '$const64.29'}), (66, {'index': '$const64.29', 'target': '$a62.28', 'res': '$66binary_subscr.30'}), (68, {'res': '$b68.31'}), (70, {'res': '$const70.32'}), (72, {'index': '$const70.32', 'target': '$b68.31', 'res': '$72binary_subscr.33'}), (74, {'lhs': '$66binary_subscr.30', 'rhs': '$72binary_subscr.33', 'res': '$74binary_multiply.34'}), (76, {'lhs': '$60binary_multiply.27', 'rhs': '$74binary_multiply.34', 'res': '$76binary_subtract.35'}), (78, {'res': '$c78.36'}), (80, {'res': '$const80.37'}), (82, {'target': '$c78.36', 'index': '$const80.37', 'value': '$76binary_subtract.35'}), (84, {'res': '$a84.38'}), (86, {'res': '$const86.39'}), (88, {'index': '$const86.39', 'target': '$a84.38', 'res': '$88binary_subscr.40'}), (90, {'res': '$b90.41'}), (92, {'res': '$const92.42'}), (94, {'index': '$const92.42', 'target': '$b90.41', 'res': '$94binary_subscr.43'}), (96, {'lhs': '$88binary_subscr.40', 'rhs': '$94binary_subscr.43', 'res': '$96binary_multiply.44'}), (98, {'res': '$a98.45'}), (100, {'res': '$const100.46'}), (102, {'index': '$const100.46', 'target': '$a98.45', 'res': '$102binary_subscr.47'}), (104, {'res': '$b104.48'}), (106, {'res': '$const106.49'}), (108, {'index': '$const106.49', 'target': '$b104.48', 'res': '$108binary_subscr.50'}), (110, {'lhs': '$102binary_subscr.47', 'rhs': '$108binary_subscr.50', 'res': '$110binary_multiply.51'}), (112, {'lhs': '$96binary_multiply.44', 'rhs': '$110binary_multiply.51', 'res': '$112binary_subtract.52'}), (114, {'res': '$c114.53'}), (116, {'res': '$const116.54'}), (118, {'target': '$c114.53', 'index': '$const116.54', 'value': '$112binary_subtract.52'}), (120, {'res': '$c120.55'}), (122, {'retval': '$c120.55', 'castval': '$122return_value.56'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = getitem(value=a, index=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = getitem(value=b, index=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = getitem(value=a, index=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = getitem(value=b, index=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[$const44.20] = $40binary_subtract.18   ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = getitem(value=a, index=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = getitem(value=b, index=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = getitem(value=a, index=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = getitem(value=b, index=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[$const80.37] = $76binary_subtract.35   ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = getitem(value=a, index=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = getitem(value=b, index=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = getitem(value=a, index=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = getitem(value=b, index=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[$const116.54] = $112binary_subtract.52 ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b80b61129e8>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: b = arg(1, name=b)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $const6.2 = const(int, 3)
# DEBUG:numba.core.ssa:on stmt: $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: c = $8call_method.3
# DEBUG:numba.core.ssa:on stmt: $const14.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5)
# DEBUG:numba.core.ssa:on stmt: $const20.8 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8)
# DEBUG:numba.core.ssa:on stmt: $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9
# DEBUG:numba.core.ssa:on stmt: $const28.12 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12)
# DEBUG:numba.core.ssa:on stmt: $const34.15 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15)
# DEBUG:numba.core.ssa:on stmt: $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16
# DEBUG:numba.core.ssa:on stmt: $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17
# DEBUG:numba.core.ssa:on stmt: $const44.20 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: c[0] = $40binary_subtract.18
# DEBUG:numba.core.ssa:on stmt: $const50.22 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22)
# DEBUG:numba.core.ssa:on stmt: $const56.25 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25)
# DEBUG:numba.core.ssa:on stmt: $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26
# DEBUG:numba.core.ssa:on stmt: $const64.29 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29)
# DEBUG:numba.core.ssa:on stmt: $const70.32 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32)
# DEBUG:numba.core.ssa:on stmt: $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33
# DEBUG:numba.core.ssa:on stmt: $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34
# DEBUG:numba.core.ssa:on stmt: $const80.37 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: c[1] = $76binary_subtract.35
# DEBUG:numba.core.ssa:on stmt: $const86.39 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39)
# DEBUG:numba.core.ssa:on stmt: $const92.42 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42)
# DEBUG:numba.core.ssa:on stmt: $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43
# DEBUG:numba.core.ssa:on stmt: $const100.46 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46)
# DEBUG:numba.core.ssa:on stmt: $const106.49 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49)
# DEBUG:numba.core.ssa:on stmt: $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50
# DEBUG:numba.core.ssa:on stmt: $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51
# DEBUG:numba.core.ssa:on stmt: $const116.54 = const(int, 2)
# DEBUG:numba.core.ssa:on stmt: c[2] = $112binary_subtract.52
# DEBUG:numba.core.ssa:on stmt: $122return_value.56 = cast(value=c)
# DEBUG:numba.core.ssa:on stmt: return $122return_value.56
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$102binary_subscr.47': [<numba.core.ir.Assign object at 0x2b80b617c358>],
#              '$108binary_subscr.50': [<numba.core.ir.Assign object at 0x2b80b617c3c8>],
#              '$110binary_multiply.51': [<numba.core.ir.Assign object at 0x2b80b616db00>],
#              '$112binary_subtract.52': [<numba.core.ir.Assign object at 0x2b80b616dbe0>],
#              '$122return_value.56': [<numba.core.ir.Assign object at 0x2b80b616df60>],
#              '$16binary_subscr.6': [<numba.core.ir.Assign object at 0x2b80b616d2b0>],
#              '$22binary_subscr.9': [<numba.core.ir.Assign object at 0x2b80b616d860>],
#              '$24binary_multiply.10': [<numba.core.ir.Assign object at 0x2b80b6161860>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b80b6148f60>],
#              '$30binary_subscr.13': [<numba.core.ir.Assign object at 0x2b80b616de80>],
#              '$36binary_subscr.16': [<numba.core.ir.Assign object at 0x2b80b617c048>],
#              '$38binary_multiply.17': [<numba.core.ir.Assign object at 0x2b80b6161e10>],
#              '$40binary_subtract.18': [<numba.core.ir.Assign object at 0x2b80b6161ef0>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b80b6161048>],
#              '$52binary_subscr.23': [<numba.core.ir.Assign object at 0x2b80b617c0b8>],
#              '$58binary_subscr.26': [<numba.core.ir.Assign object at 0x2b80b617c128>],
#              '$60binary_multiply.27': [<numba.core.ir.Assign object at 0x2b80b61696d8>],
#              '$66binary_subscr.30': [<numba.core.ir.Assign object at 0x2b80b617c198>],
#              '$72binary_subscr.33': [<numba.core.ir.Assign object at 0x2b80b617c208>],
#              '$74binary_multiply.34': [<numba.core.ir.Assign object at 0x2b80b6169c88>],
#              '$76binary_subtract.35': [<numba.core.ir.Assign object at 0x2b80b6169d68>],
#              '$88binary_subscr.40': [<numba.core.ir.Assign object at 0x2b80b617c278>],
#              '$8call_method.3': [<numba.core.ir.Assign object at 0x2b80b6161208>],
#              '$94binary_subscr.43': [<numba.core.ir.Assign object at 0x2b80b617c2e8>],
#              '$96binary_multiply.44': [<numba.core.ir.Assign object at 0x2b80b616d550>],
#              '$const100.46': [<numba.core.ir.Assign object at 0x2b80b616d6d8>],
#              '$const106.49': [<numba.core.ir.Assign object at 0x2b80b616d940>],
#              '$const116.54': [<numba.core.ir.Assign object at 0x2b80b616dd68>],
#              '$const14.5': [<numba.core.ir.Assign object at 0x2b80b6161438>],
#              '$const20.8': [<numba.core.ir.Assign object at 0x2b80b61616a0>],
#              '$const28.12': [<numba.core.ir.Assign object at 0x2b80b61619e8>],
#              '$const34.15': [<numba.core.ir.Assign object at 0x2b80b6161c50>],
#              '$const44.20': [<numba.core.ir.Assign object at 0x2b80b61690b8>],
#              '$const50.22': [<numba.core.ir.Assign object at 0x2b80b61692b0>],
#              '$const56.25': [<numba.core.ir.Assign object at 0x2b80b6169518>],
#              '$const6.2': [<numba.core.ir.Assign object at 0x2b80b6161128>],
#              '$const64.29': [<numba.core.ir.Assign object at 0x2b80b6169860>],
#              '$const70.32': [<numba.core.ir.Assign object at 0x2b80b6169ac8>],
#              '$const80.37': [<numba.core.ir.Assign object at 0x2b80b6169ef0>],
#              '$const86.39': [<numba.core.ir.Assign object at 0x2b80b616d128>],
#              '$const92.42': [<numba.core.ir.Assign object at 0x2b80b616d390>],
#              'a': [<numba.core.ir.Assign object at 0x2b80b6148da0>],
#              'b': [<numba.core.ir.Assign object at 0x2b80b6148e48>],
#              'c': [<numba.core.ir.Assign object at 0x2b80b61612b0>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_method.1']
#     $const6.2 = const(int, 3)                ['$const6.2']
#     $8call_method.3 = call $4load_method.1($const6.2, func=$4load_method.1, args=[Var($const6.2, coordinate_numba.py:6)], kws=(), vararg=None) ['$4load_method.1', '$8call_method.3', '$const6.2']
#     c = $8call_method.3                      ['$8call_method.3', 'c']
#     $const14.5 = const(int, 1)               ['$const14.5']
#     $16binary_subscr.6 = static_getitem(value=a, index=1, index_var=$const14.5) ['$16binary_subscr.6', '$const14.5', 'a']
#     $const20.8 = const(int, 2)               ['$const20.8']
#     $22binary_subscr.9 = static_getitem(value=b, index=2, index_var=$const20.8) ['$22binary_subscr.9', '$const20.8', 'b']
#     $24binary_multiply.10 = $16binary_subscr.6 * $22binary_subscr.9 ['$16binary_subscr.6', '$22binary_subscr.9', '$24binary_multiply.10']
#     $const28.12 = const(int, 2)              ['$const28.12']
#     $30binary_subscr.13 = static_getitem(value=a, index=2, index_var=$const28.12) ['$30binary_subscr.13', '$const28.12', 'a']
#     $const34.15 = const(int, 1)              ['$const34.15']
#     $36binary_subscr.16 = static_getitem(value=b, index=1, index_var=$const34.15) ['$36binary_subscr.16', '$const34.15', 'b']
#     $38binary_multiply.17 = $30binary_subscr.13 * $36binary_subscr.16 ['$30binary_subscr.13', '$36binary_subscr.16', '$38binary_multiply.17']
#     $40binary_subtract.18 = $24binary_multiply.10 - $38binary_multiply.17 ['$24binary_multiply.10', '$38binary_multiply.17', '$40binary_subtract.18']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     c[0] = $40binary_subtract.18             ['$40binary_subtract.18', '$const44.20', 'c']
#     $const50.22 = const(int, 2)              ['$const50.22']
#     $52binary_subscr.23 = static_getitem(value=a, index=2, index_var=$const50.22) ['$52binary_subscr.23', '$const50.22', 'a']
#     $const56.25 = const(int, 0)              ['$const56.25']
#     $58binary_subscr.26 = static_getitem(value=b, index=0, index_var=$const56.25) ['$58binary_subscr.26', '$const56.25', 'b']
#     $60binary_multiply.27 = $52binary_subscr.23 * $58binary_subscr.26 ['$52binary_subscr.23', '$58binary_subscr.26', '$60binary_multiply.27']
#     $const64.29 = const(int, 0)              ['$const64.29']
#     $66binary_subscr.30 = static_getitem(value=a, index=0, index_var=$const64.29) ['$66binary_subscr.30', '$const64.29', 'a']
#     $const70.32 = const(int, 2)              ['$const70.32']
#     $72binary_subscr.33 = static_getitem(value=b, index=2, index_var=$const70.32) ['$72binary_subscr.33', '$const70.32', 'b']
#     $74binary_multiply.34 = $66binary_subscr.30 * $72binary_subscr.33 ['$66binary_subscr.30', '$72binary_subscr.33', '$74binary_multiply.34']
#     $76binary_subtract.35 = $60binary_multiply.27 - $74binary_multiply.34 ['$60binary_multiply.27', '$74binary_multiply.34', '$76binary_subtract.35']
#     $const80.37 = const(int, 1)              ['$const80.37']
#     c[1] = $76binary_subtract.35             ['$76binary_subtract.35', '$const80.37', 'c']
#     $const86.39 = const(int, 0)              ['$const86.39']
#     $88binary_subscr.40 = static_getitem(value=a, index=0, index_var=$const86.39) ['$88binary_subscr.40', '$const86.39', 'a']
#     $const92.42 = const(int, 1)              ['$const92.42']
#     $94binary_subscr.43 = static_getitem(value=b, index=1, index_var=$const92.42) ['$94binary_subscr.43', '$const92.42', 'b']
#     $96binary_multiply.44 = $88binary_subscr.40 * $94binary_subscr.43 ['$88binary_subscr.40', '$94binary_subscr.43', '$96binary_multiply.44']
#     $const100.46 = const(int, 1)             ['$const100.46']
#     $102binary_subscr.47 = static_getitem(value=a, index=1, index_var=$const100.46) ['$102binary_subscr.47', '$const100.46', 'a']
#     $const106.49 = const(int, 0)             ['$const106.49']
#     $108binary_subscr.50 = static_getitem(value=b, index=0, index_var=$const106.49) ['$108binary_subscr.50', '$const106.49', 'b']
#     $110binary_multiply.51 = $102binary_subscr.47 * $108binary_subscr.50 ['$102binary_subscr.47', '$108binary_subscr.50', '$110binary_multiply.51']
#     $112binary_subtract.52 = $96binary_multiply.44 - $110binary_multiply.51 ['$110binary_multiply.51', '$112binary_subtract.52', '$96binary_multiply.44']
#     $const116.54 = const(int, 2)             ['$const116.54']
#     c[2] = $112binary_subtract.52            ['$112binary_subtract.52', '$const116.54', 'c']
#     $122return_value.56 = cast(value=c)      ['$122return_value.56', 'c']
#     return $122return_value.56               ['$122return_value.56']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=14)
#            2	LOAD_GLOBAL(arg=0, lineno=14)
#            4	LOAD_METHOD(arg=1, lineno=14)
#            6	LOAD_FAST(arg=0, lineno=14)
#            8	LOAD_FAST(arg=0, lineno=14)
#           10	CALL_METHOD(arg=2, lineno=14)
#           12	STORE_FAST(arg=1, lineno=14)
#           14	LOAD_GLOBAL(arg=0, lineno=15)
#           16	LOAD_METHOD(arg=2, lineno=15)
#           18	LOAD_FAST(arg=1, lineno=15)
#           20	CALL_METHOD(arg=1, lineno=15)
#           22	RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_METHOD(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=LOAD_FAST(arg=0, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=CALL_METHOD(arg=2, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$4load_method.1', '$a6.2', '$a8.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=STORE_FAST(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$10call_method.4']
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_GLOBAL(arg=0, lineno=15)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_METHOD(arg=2, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$14load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=CALL_METHOD(arg=1, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$16load_method.6', '$n_218.7']
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=RETURN_VALUE(arg=None, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$20call_method.8']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_method.1'}), (6, {'res': '$a6.2'}), (8, {'res': '$a8.3'}), (10, {'func': '$4load_method.1', 'args': ['$a6.2', '$a8.3'], 'res': '$10call_method.4'}), (12, {'value': '$10call_method.4'}), (14, {'res': '$14load_global.5'}), (16, {'item': '$14load_global.5', 'res': '$16load_method.6'}), (18, {'res': '$n_218.7'}), (20, {'func': '$16load_method.6', 'args': ['$n_218.7'], 'res': '$20call_method.8'}), (22, {'retval': '$20call_method.8', 'castval': '$22return_value.9'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
#     $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$14load_global.5']
#     $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt) ['$14load_global.5', '$16load_method.6']
#     $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$16load_method.6', '$20call_method.8', 'n_2']
#     $22return_value.9 = cast(value=$20call_method.8) ['$20call_method.8', '$22return_value.9']
#     return $22return_value.9                 ['$22return_value.9']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b80b63720f0>
# DEBUG:numba.core.ssa:on stmt: a = arg(0, name=a)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_method.1 = getattr(value=$2load_global.0, attr=dot)
# DEBUG:numba.core.ssa:on stmt: $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: n_2 = $10call_method.4
# DEBUG:numba.core.ssa:on stmt: $14load_global.5 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $16load_method.6 = getattr(value=$14load_global.5, attr=sqrt)
# DEBUG:numba.core.ssa:on stmt: $20call_method.8 = call $16load_method.6(n_2, func=$16load_method.6, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None)
# DEBUG:numba.core.ssa:on stmt: $22return_value.9 = cast(value=$20call_method.8)
# DEBUG:numba.core.ssa:on stmt: return $22return_value.9
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$10call_method.4': [<numba.core.ir.Assign object at 0x2b80b61e8358>],
#              '$14load_global.5': [<numba.core.ir.Assign object at 0x2b80b61e84e0>],
#              '$16load_method.6': [<numba.core.ir.Assign object at 0x2b80b61e85c0>],
#              '$20call_method.8': [<numba.core.ir.Assign object at 0x2b80b61e8828>],
#              '$22return_value.9': [<numba.core.ir.Assign object at 0x2b80b61e8978>],
#              '$2load_global.0': [<numba.core.ir.Assign object at 0x2b80b61e8080>],
#              '$4load_method.1': [<numba.core.ir.Assign object at 0x2b80b61e8160>],
#              'a': [<numba.core.ir.Assign object at 0x2b80b6112ac8>],
#              'n_2': [<numba.core.ir.Assign object at 0x2b80b61e8400>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     a = arg(0, name=a)                       ['a']
#     $2load_global.0 = global(np: <module 'numpy' from '/home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_method.1 = getattr(value=$2load_global.0, attr=dot) ['$2load_global.0', '$4load_method.1']
#     $10call_method.4 = call $4load_method.1(a, a, func=$4load_method.1, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$10call_method.4', '$4load_method.1', 'a', 'a']
#     n_2 = $10call_method.4                   ['$10call_method.4', 'n_2']
# ...
# DEBUG:numba.core.ssa:on stmt: angle_position_2 = arg(0, name=angle_position_2)
# DEBUG:numba.core.ssa:on stmt: torsion_position_1 = arg(1, name=torsion_position_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_subtract.2 = angle_position_2 - torsion_position_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_subtract.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_subtract.2': [<numba.core.ir.Assign object at 0x2b80b674bd30>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b80b674be10>],
#              'angle_position_2': [<numba.core.ir.Assign object at 0x2b80b674ba58>],
#              'torsion_position_1': [<numba.core.ir.Assign object at 0x2b80b674bb00>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     angle_position_2 = arg(0, name=angle_position_2) ['angle_position_2']
#     torsion_position_1 = arg(1, name=torsion_position_1) ['torsion_position_1']
#     $6binary_subtract.2 = angle_position_2 - torsion_position_1 ['$6binary_subtract.2', 'angle_position_2', 'torsion_position_1']
#     $8return_value.3 = cast(value=$6binary_subtract.2) ['$6binary_subtract.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=106)
#            2	LOAD_FAST(arg=1, lineno=106)
#            4	LOAD_FAST(arg=0, lineno=110)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=110)
#            8	RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=106)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$a_12.0', '$_32call_function_12_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=110)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$a_12.0'}), (4, {'res': '$_32call_function_12_14.1'}), (6, {'lhs': '$a_12.0', 'rhs': '$_32call_function_12_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b80b6660f60>
# DEBUG:numba.core.ssa:on stmt: _32call_function_12_1 = arg(0, name=_32call_function_12_1)
# DEBUG:numba.core.ssa:on stmt: a_1 = arg(1, name=a_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = a_1 / _32call_function_12_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b80b6661390>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b80b6661470>],
#              '_32call_function_12_1': [<numba.core.ir.Assign object at 0x2b80b66610b8>],
#              'a_1': [<numba.core.ir.Assign object at 0x2b80b6661160>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _32call_function_12_1 = arg(0, name=_32call_function_12_1) ['_32call_function_12_1']
#     a_1 = arg(1, name=a_1)                   ['a_1']
#     $6binary_true_divide.2 = a_1 / _32call_function_12_1 ['$6binary_true_divide.2', '_32call_function_12_1', 'a_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=107)
#            2	LOAD_FAST(arg=1, lineno=107)
#            4	LOAD_FAST(arg=0, lineno=111)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=111)
#            8	RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=107)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$b_12.0', '$_44call_function_17_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=111)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$b_12.0'}), (4, {'res': '$_44call_function_17_14.1'}), (6, {'lhs': '$b_12.0', 'rhs': '$_44call_function_17_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b80b6610f60>
# DEBUG:numba.core.ssa:on stmt: _44call_function_17_1 = arg(0, name=_44call_function_17_1)
# DEBUG:numba.core.ssa:on stmt: b_1 = arg(1, name=b_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = b_1 / _44call_function_17_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b80b6602518>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b80b66025f8>],
#              '_44call_function_17_1': [<numba.core.ir.Assign object at 0x2b80b6602240>],
#              'b_1': [<numba.core.ir.Assign object at 0x2b80b66022e8>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _44call_function_17_1 = arg(0, name=_44call_function_17_1) ['_44call_function_17_1']
#     b_1 = arg(1, name=b_1)                   ['b_1']
#     $6binary_true_divide.2 = b_1 / _44call_function_17_1 ['$6binary_true_divide.2', '_44call_function_17_1', 'b_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=109)
#            2	LOAD_FAST(arg=1, lineno=109)
#            4	LOAD_FAST(arg=0, lineno=112)
#            6	BINARY_TRUE_DIVIDE(arg=None, lineno=112)
#            8	RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_FAST(arg=1, lineno=109)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=BINARY_TRUE_DIVIDE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$c_12.0', '$_56call_function_22_14.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=RETURN_VALUE(arg=None, lineno=112)
# DEBUG:numba.core.byteflow:stack ['$6binary_true_divide.2']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$c_12.0'}), (4, {'res': '$_56call_function_22_14.1'}), (6, {'lhs': '$c_12.0', 'rhs': '$_56call_function_22_14.1', 'res': '$6binary_true_divide.2'}), (8, {'retval': '$6binary_true_divide.2', 'castval': '$8return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:-----------------------------------BEFORE SSA-----------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b80b6259b38>
# DEBUG:numba.core.ssa:on stmt: _56call_function_22_1 = arg(0, name=_56call_function_22_1)
# DEBUG:numba.core.ssa:on stmt: c_1 = arg(1, name=c_1)
# DEBUG:numba.core.ssa:on stmt: $6binary_true_divide.2 = c_1 / _56call_function_22_1
# DEBUG:numba.core.ssa:on stmt: $8return_value.3 = cast(value=$6binary_true_divide.2)
# DEBUG:numba.core.ssa:on stmt: return $8return_value.3
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$6binary_true_divide.2': [<numba.core.ir.Assign object at 0x2b80b6b57cc0>],
#              '$8return_value.3': [<numba.core.ir.Assign object at 0x2b80b6b57da0>],
#              '_56call_function_22_1': [<numba.core.ir.Assign object at 0x2b80b6b575f8>],
#              'c_1': [<numba.core.ir.Assign object at 0x2b80b6b57a90>]})
# DEBUG:numba.core.ssa:SSA violators set()
# DEBUG:numba.core.ssa:-----------------------------------AFTER SSA------------------------------------
# DEBUG:numba.core.ssa:label 0:
#     _56call_function_22_1 = arg(0, name=_56call_function_22_1) ['_56call_function_22_1']
#     c_1 = arg(1, name=c_1)                   ['c_1']
#     $6binary_true_divide.2 = c_1 / _56call_function_22_1 ['$6binary_true_divide.2', '_56call_function_22_1', 'c_1']
#     $8return_value.3 = cast(value=$6binary_true_divide.2) ['$6binary_true_divide.2', '$8return_value.3']
#     return $8return_value.3                  ['$8return_value.3']
#
# DEBUG:numba.core.ssa:================================================================================
# RDKit WARNING: [17:44:49] Enabling RDKit 2019.09.3 jupyter extensions

# %% [markdown]
# I'll generate a capped alanine and a corresponding system generator.

# %%
atp, sys_generator = generate_atp('vacuum')
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %% [markdown]
# I'll generate a `htf_og` and a `htf_rep` corresponding to the original htf and a repartitioned htf. The function that is called iternally does a `validate_endstate_energies` which will print the energetic contribution by force, bookkeep, and print the discrepancy between the alchemical and nonalchemical endstates.

# %%
htf_og = generate_dipeptide_top_pos_sys(atp.topology, 'THR', atp.system, atp.positions, sys_generator, conduct_htf_prop=True)
htf_rep = generate_dipeptide_top_pos_sys(atp.topology, 'THR', atp.system, atp.positions, sys_generator, conduct_htf_prop=True, repartition=True)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{4: 4, 9: 9}]
# INFO:proposal_generator:{4: 4, 9: 9}
# INFO:proposal_generator:Only one map so returning that one
# INFO:proposal_generator:{4: 4, 9: 9}
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 7
# INFO:geometry:Atom index proposal order is [14, 18, 13, 19, 15, 17, 16]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# making topology proposal
# generating geometry engine
# making geometry proposal from ALA to THR
# INFO:geometry:		there are 121 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (14, 10, 8, 18, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 2])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -12.86077001571492
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context new positions
# INFO:geometry:There are 7 new atoms
# INFO:geometry:	reduced angle potential = 0.22878255850864945.
# INFO:geometry:	reduced angle potential = 0.017520669287988268.
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning CPU platform instead of requested platform CUDA
# conducting subsequent work with the following platform: CPU
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:	reduced angle potential = 0.6061606804243588.
# INFO:geometry:	reduced angle potential = 0.382755220342832.
# INFO:geometry:	reduced angle potential = 0.733972492777801.
# INFO:geometry:	reduced angle potential = 1.4165993631916218.
# INFO:geometry:	reduced angle potential = 0.3223941418295565.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# INFO:geometry:total reduced potential before atom placement: 16.81404844848707
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced energy added from growth system: -52.768819013405825
# INFO:geometry:final reduced energy -35.95477056491874
# INFO:geometry:sum of energies: -35.95477056491875
# INFO:geometry:magnitude of difference in the energies: 1.4210854715202004e-14
# INFO:geometry:Final logp_proposal: 33.12421964372627
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 3
# INFO:geometry:Atom index proposal order is [11, 12, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.0875963352323845
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# added energy components: [('CustomBondForce', 1.9081755690650963), ('CustomAngleForce', 6.290667564005209), ('CustomTorsionForce', 13.890938880808843), ('CustomBondForce', -74.85860102728498)]
# INFO:geometry:setting atoms_with_positions context old positions
# INFO:geometry:There are 3 new atoms
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 3.205828670443744e-13.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced potential before atom placement: 16.81404844848707
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced energy added from growth system: 8.81651504972902
# INFO:geometry:final reduced energy 25.630563498216084
# INFO:geometry:sum of energies: 25.63056349821609
# INFO:geometry:magnitude of difference in the energies: 7.105427357601002e-15
# INFO:geometry:Final logp_proposal: 12.201608903097725
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b80b9b53720> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b80b9b534b0> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are old or new system exceptions...proceeding.
# added energy components: [('CustomBondForce', 0.0), ('CustomAngleForce', 0.00017809232534266413), ('CustomTorsionForce', 0.004336750525590176), ('CustomBondForce', 8.812000206878086)]
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			HarmonicBondForce: 0.03455153971697946
# 			HarmonicAngleForce: 0.607201772364288
# 			PeriodicTorsionForce: 16.17680997925674
# 			NonbondedForce: -39.18689400420742
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			CustomBondForce: 1.9427271087820759
# 			HarmonicBondForce: 0.0
# 			CustomAngleForce: 6.897869336369497
# 			HarmonicAngleForce: 0.0
# 			CustomTorsionForce: 30.06774886006558
# 			PeriodicTorsionForce: 0.0
# 			NonbondedForce: 0.0
# 			CustomNonbondedForce: 4.716815192504041
# 			CustomNonbondedForce: -134.404026980247
# 			CustomBondForce: 15.641716756250577
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			CustomBondForce: 1.9427271087820759
# 			HarmonicBondForce: 0.0
# 			CustomAngleForce: 6.897869336369497
# 			HarmonicAngleForce: 0.0
# 			CustomTorsionForce: 30.06774886006558
# 			PeriodicTorsionForce: 0.0
# 			NonbondedForce: 18.124038038450035
# 			CustomNonbondedForce: 333.95204454489095
# 			CustomNonbondedForce: -77.97141392932234
# 			CustomBondForce: -0.6746425965222614
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			HarmonicBondForce: 1.9427271087820759
# 			HarmonicAngleForce: 6.897691244044153
# 			PeriodicTorsionForce: 30.063412109539993
# 			NonbondedForce: 263.98337555072345
# 			AndersenThermostat: 0.0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-52f62a08328f> in <module>
# ----> 1 htf_og = generate_dipeptide_top_pos_sys(atp.topology, 'THR', atp.system, atp.positions, sys_generator, conduct_htf_prop=True)
#       2 htf_rep = generate_dipeptide_top_pos_sys(atp.topology, 'THR', atp.system, atp.positions, sys_generator, conduct_htf_prop=True, repartition=True)
#       3
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/perses-0.7.3.dev0-py3.7.egg/perses/tests/test_topology_proposal.py in generate_dipeptide_top_pos_sys(topology, new_res, system, positions, system_generator, conduct_geometry_prop, conduct_htf_prop, repartition, validate_energy_bookkeeping)
#     317             subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential
#     318
# --> 319         zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'))
#     320         print(f"zero state error : {zero_state_error}")
#     321         print(f"one state error : {one_state_error}")
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/perses-0.7.3.dev0-py3.7.egg/perses/tests/utils.py in validate_endstate_energies(topology_proposal, htf, added_energy, subtracted_energy, beta, ENERGY_THRESHOLD, platform, trajectory_directory)
#     802     assert ratio < ENERGY_THRESHOLD, f"The ratio in energy difference for the ZERO state is {ratio}.\n This is greater than the threshold of {ENERGY_THRESHOLD}.\n real-zero: {nonalch_zero_rp} \n alc-zero: {alch_zero_rp} \nadded-valence: {added_energy}"
#     803     ratio = abs((nonalch_one_rp - alch_one_rp + subtracted_energy) / (nonalch_one_rp + alch_one_rp + subtracted_energy))
# --> 804     assert ratio < ENERGY_THRESHOLD, f"The ratio in energy difference for the ONE state is {ratio}.\n This is greater than the threshold of {ENERGY_THRESHOLD}.\n real-one: {nonalch_one_rp} \n alc-one: {alch_one_rp} \nsubtracted-valence: {subtracted_energy}"
#     805
#     806
#
# AssertionError: The ratio in energy difference for the ONE state is 0.001016999185789033.
#  This is greater than the threshold of 1e-06.
#  real-one: 302.8872060130897
#  alc-one: 312.3383713627136
# subtracted-valence: 8.816515049729013

# %% [markdown]
# Let's write a function that removes exceptions from the non-bonded force to see if that gets rid of the discrepancy at the ONE state

# %%
def remove_exceptions(system, i):
    # Get nonbonded force
    force = system.getForce(i)
    
    # Get number of exceptions
    print(f"number of exceptions before: {system.getForce(i).getNumExceptions()}")
    
    # Create nonbonded force without exceptions
    new_force = openmm.NonbondedForce()
    for j in range(force.getNumParticles()):
        parameters = force.getParticleParameters(j)
        new_force.addParticle(parameters[0], parameters[1], parameters[2])
    
    # Remove old nonbonded force
    system.removeForce(i)
    
    # Add new nonbonded force
    system.addForce(new_force)
    
    # Check that there are no exceptions
    print(f"number of exception after: {system.getForce(i).getNumExceptions()}")
    
    return system

# %% [markdown]
# Remove exceptions from nonbonded force for alanine dipeptide

# %%
new_system = remove_exceptions(atp.system, 3)
# Out:
# number of exceptions before: 98
# number of exception after: 0

# %%
from perses.rjmc.topology_proposal import PointMutationEngine
point_mutation_engine = PointMutationEngine(wildtype_topology = atp.topology,
                                            system_generator = sys_generator,
                                            chain_id = '1', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', 'THR')], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation

# %%
topology_proposal = point_mutation_engine.propose(current_system = new_system, current_topology = atp.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{4: 4, 9: 9}]
# INFO:proposal_generator:{4: 4, 9: 9}
# INFO:proposal_generator:Only one map so returning that one
# INFO:proposal_generator:{4: 4, 9: 9}

# %%
for i in range(topology_proposal.new_system.getNumForces()):
    print(topology_proposal.new_system.getForce(i))
# Out:
# <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x2b80b9b539c0> >
# <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x2b80b9b539c0> >
# <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x2b80b9b539c0> >
# <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b80b9b539c0> >

# %%
# Do this for new system as well (as generated by topology proposal)
topology_proposal._new_system = remove_exceptions(topology_proposal.new_system, 3)
# Out:
# number of exceptions before: 121
# number of exception after: 0

# %%
# Run repartitioned htf and see if the discrepancy is gone
from perses.rjmc.geometry import FFAllAngleGeometryEngine
geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)

# %%
from openmmtools.constants import kB
temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT


forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, atp.positions, beta, validate_energy_bookkeeping=True)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, atp.positions, beta, validate_energy_bookkeeping=True)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 7
# INFO:geometry:Atom index proposal order is [18, 14, 17, 15, 16, 13, 19]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# /home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/parmed/openmm/topsystem.py:451: OpenMMWarning: Detected incomplete exceptions. Not supported.
#   warnings.warn('Detected incomplete exceptions. Not supported.', OpenMMWarning)
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 11 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 43 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 72 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		there are no Exceptions in the reference system.
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (18, 10, 8, 14, [1, Quantity(value=-1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 2])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -12.966130531372746
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context new positions
# INFO:geometry:There are 7 new atoms
# INFO:geometry:	reduced angle potential = 0.052896290685603885.
# INFO:geometry:	reduced angle potential = 0.3031412002189764.
# INFO:geometry:	reduced angle potential = 0.08294483554734398.
# INFO:geometry:	reduced angle potential = 2.3029923640333196.
# INFO:geometry:	reduced angle potential = 0.03499449290572153.
# INFO:geometry:	reduced angle potential = 0.08706942616663603.
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:	reduced angle potential = 0.043552731174432306.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 11 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 43 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 72 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# INFO:geometry:total reduced potential before atom placement: 16.81404844848707
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced energy added from growth system: 20.876182283743834
# INFO:geometry:final reduced energy 37.69023073223092
# INFO:geometry:sum of energies: 37.6902307322309
# INFO:geometry:magnitude of difference in the energies: 1.7763568394002505e-14
# INFO:geometry:Final logp_proposal: 33.864123741040316
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 3
# INFO:geometry:Atom index proposal order is [12, 11, 13]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# /home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/parmed/openmm/topsystem.py:451: OpenMMWarning: Detected incomplete exceptions. Not supported.
#   warnings.warn('Detected incomplete exceptions. Not supported.', OpenMMWarning)
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		there are no Exceptions in the reference system.
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.0875963352323845
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# added energy components: [('CustomBondForce', 0.33255633092947423), ('CustomAngleForce', 8.605684611216772), ('CustomTorsionForce', 11.937941341597588)]
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# INFO:geometry:setting atoms_with_positions context old positions
# INFO:geometry:There are 3 new atoms
# INFO:geometry:	reduced angle potential = 3.205828670443744e-13.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced potential before atom placement: 16.81404844848707
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced energy added from growth system: 0.00451484285093284
# INFO:geometry:final reduced energy 16.818563291338002
# INFO:geometry:sum of energies: 16.818563291338005
# INFO:geometry:magnitude of difference in the energies: 2.105954299835844e-15
# INFO:geometry:Final logp_proposal: 14.352172980351355
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# added energy components: [('CustomBondForce', 0.0), ('CustomAngleForce', 0.00017809232534266413), ('CustomTorsionForce', 0.004336750525590176)]

# %%
#create a hybrid topology factory
from perses.tests.utils import validate_endstate_energies
ENERGY_THRESHOLD = 1e-6

from perses.annihilation.relative import HybridTopologyFactory
forward_htf = HybridTopologyFactory(topology_proposal = topology_proposal,
             current_positions =  atp.positions,
             new_positions = forward_new_positions,
             repartition = True,
             use_dispersion_correction = False,
             functions=None,
             softcore_alpha = None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new = False,
             neglected_new_angle_terms = [],
             neglected_old_angle_terms = [],
             softcore_LJ_v2 = True,
             softcore_electrostatics = True,
             softcore_LJ_v2_alpha = 0.85,
             softcore_electrostatics_alpha = 0.3,
             softcore_sigma_Q = 1.0,
             interpolate_old_and_new_14s = False,
             omitted_terms = None)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'))
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b80b9b53780> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b80b9b536f0> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are no old/new system exceptions.
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			HarmonicBondForce: 0.03455153971697946
# 			HarmonicAngleForce: 0.607201772364288
# 			PeriodicTorsionForce: 16.17680997925674
# 			NonbondedForce: 837463.0086549831
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			CustomBondForce: 0.36710787064645367
# 			HarmonicBondForce: 0.0
# 			CustomAngleForce: 9.21288638358106
# 			HarmonicAngleForce: 0.0
# 			CustomTorsionForce: 28.114751320854335
# 			PeriodicTorsionForce: 0.0
# 			NonbondedForce: 3.4141254500551264
# 			CustomNonbondedForce: 838057.0053637062
# 			CustomNonbondedForce: -593.9967087223318
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			CustomBondForce: 0.36710787064645367
# 			HarmonicBondForce: 0.0
# 			CustomAngleForce: 9.21288638358106
# 			HarmonicAngleForce: 0.0
# 			CustomTorsionForce: 28.114751320854335
# 			PeriodicTorsionForce: 0.0
# 			NonbondedForce: -174.40073394953055
# 			CustomNonbondedForce: 910439.074393809
# 			CustomNonbondedForce: -832.529638414241
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			HarmonicBondForce: 0.36710787064645367
# 			HarmonicAngleForce: 9.212708291255717
# 			PeriodicTorsionForce: 28.11041457032875
# 			NonbondedForce: 909606.5447553946
# 			AndersenThermostat: 0.0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-e52323385976> in <module>
#      38     subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential
#      39
# ---> 40 zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD, platform = openmm.Platform.getPlatformByName('Reference'))
#      41 print(f"zero state error : {zero_state_error}")
#      42 print(f"one state error : {one_state_error}")
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/perses-0.7.3.dev0-py3.7.egg/perses/tests/utils.py in validate_endstate_energies(topology_proposal, htf, added_energy, subtracted_energy, beta, ENERGY_THRESHOLD, platform, trajectory_directory)
#     800
#     801     ratio = abs((nonalch_zero_rp - alch_zero_rp + added_energy) / (nonalch_zero_rp + alch_zero_rp + added_energy))
# --> 802     assert ratio < ENERGY_THRESHOLD, f"The ratio in energy difference for the ZERO state is {ratio}.\n This is greater than the threshold of {ENERGY_THRESHOLD}.\n real-zero: {nonalch_zero_rp} \n alc-zero: {alch_zero_rp} \nadded-valence: {added_energy}"
#     803     ratio = abs((nonalch_one_rp - alch_one_rp + subtracted_energy) / (nonalch_one_rp + alch_one_rp + subtracted_energy))
#     804     assert ratio < ENERGY_THRESHOLD, f"The ratio in energy difference for the ONE state is {ratio}.\n This is greater than the threshold of {ENERGY_THRESHOLD}.\n real-one: {nonalch_one_rp} \n alc-one: {alch_one_rp} \nsubtracted-valence: {subtracted_energy}"
#
# AssertionError: The ratio in energy difference for the ZERO state is 2.0382779846340937e-06.
#  This is greater than the threshold of 1e-06.
#  real-zero: 837479.8272182745
#  alc-zero: 837504.1175260089
# added-valence: 20.87618228374385

# %% [markdown]
# you can see that with `htf_rep` (at the bottom), the discrepancy between the $\lambda =  0,1$ endstates are around $1e-13$, so there are no valence bookkeeping errors.

# %% [markdown]
# Now let's remove exceptions for the 8-residue peptide

# %%
pdb = app.PDBFile("../input/4zuh_peptide_capped.pdb")

# %%
import numpy as np

# %%
from openmmforcefields.generators import SystemGenerator
forcefield_files = ['amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
barostat = None
system_generator = SystemGenerator(forcefields=forcefield_files,
                               barostat=barostat,
                               forcefield_kwargs={'removeCMMotion': False,
                                                    'ewaldErrorTolerance': 0.00025,
                                                    'constraints' : app.HBonds,
                                                    'hydrogenMass' : 4 * unit.amus},
                                periodic_forcefield_kwargs=None,
                                small_molecule_forcefield='gaff-2.11',
                                nonperiodic_forcefield_kwargs = {'nonbondedMethod': app.NoCutoff}, molecules=None, cache=None)
# Out:
# DEBUG:perses.forcefields.system_generators:Trying GAFFTemplateGenerator to load gaff-2.11

# %%
system = system_generator.create_system(pdb.topology) #update the parametrization scheme to amberff14sb

# %%
for i in range(system.getNumForces()):
    print(system.getForce(i))
# Out:
# <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x2b80b9cfe150> >
# <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x2b80b9cfe150> >
# <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x2b80b9cfe150> >
# <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b80b9cfe150> >

# %%
new_system = remove_exceptions(system, 3)
# Out:
# number of exceptions before: 645
# number of exception after: 0

# %%
for chain in pdb.topology.chains():
    print(chain.id, chain.index)
# Out:
# C 0

# %%
from perses.tests.utils import validate_endstate_energies

# %%
#create the point mutation engine
from perses.rjmc.topology_proposal import PointMutationEngine
new_res = "THR"
point_mutation_engine = PointMutationEngine(wildtype_topology = pdb.topology,
                                            system_generator = system_generator,
                                            chain_id = 'C', #denote the chain id allowed to mutate (it's always a string variable)
                                            max_point_mutants = 1,
                                            residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                            allowed_mutations = [('2', new_res)], #the residue ids allowed to mutate with the three-letter code allowed to change
                                            aggregate = True) #always allow aggregation

# %%
#create a top proposal
topology_proposal = point_mutation_engine.propose(current_system=new_system, current_topology=pdb.topology)
# Out:
# INFO:proposal_generator:	Conducting polymer point mutation proposal...
# INFO:proposal_generator:Using matching_criterion to chose best atom map
# INFO:proposal_generator:Scaffold has symmetry of 0
# WARNING:proposal_generator:Two molecules are not similar to have a common scaffold
# WARNING:proposal_generator:Proceeding with direct mapping of molecules, but please check atom mapping and the geometry of the ligands.
# INFO:proposal_generator:len [{4: 4, 9: 9}]
# INFO:proposal_generator:{4: 4, 9: 9}
# INFO:proposal_generator:Only one map so returning that one
# INFO:proposal_generator:{4: 4, 9: 9}

# %%
topology_proposal._new_system = remove_exceptions(topology_proposal.new_system, 3)
# Out:
# number of exceptions before: 668
# number of exception after: 0

# %%
positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in pdb.positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)

# %%
validate_energy_bookkeeping = True

temperature = 300*unit.kelvin
# Compute kT and inverse temperature.
kT = kB * temperature
beta = 1.0 / kT

#create a geometry engine
from perses.rjmc.geometry import FFAllAngleGeometryEngine
geometry_engine = FFAllAngleGeometryEngine(metadata=None,
                                       use_sterics=False,
                                       n_bond_divisions=100,
                                       n_angle_divisions=180,
                                       n_torsion_divisions=360,
                                       verbose=True,
                                       storage=None,
                                       bond_softening_constant=1.0,
                                       angle_softening_constant=1.0,
                                       neglect_angles = False,
                                       use_14_nonbondeds = True)


#make a geometry proposal forward
print(f"making geometry proposal from {list(pdb.topology.residues())[1].name} to {new_res}")
forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, positions, beta, validate_energy_bookkeeping=validate_energy_bookkeeping)
logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, positions, beta, validate_energy_bookkeeping=validate_energy_bookkeeping)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 7
# INFO:geometry:Atom index proposal order is [25, 29, 28, 24, 27, 30, 26]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# /home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/parmed/openmm/topsystem.py:451: OpenMMWarning: Detected incomplete exceptions. Not supported.
#   warnings.warn('Detected incomplete exceptions. Not supported.', OpenMMWarning)
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 63 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 225 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 429 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		there are no Exceptions in the reference system.
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {0: (25, 21, 18, 29, [1, Quantity(value=1.0655064807976995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 2])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -12.678448458920965
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context new positions
# making geometry proposal from SER to THR
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:There are 7 new atoms
# INFO:geometry:	reduced angle potential = 0.2987514870469036.
# INFO:geometry:	reduced angle potential = 0.4168125011804123.
# INFO:geometry:	reduced angle potential = 0.4416103234039798.
# INFO:geometry:	reduced angle potential = 0.6908024396468293.
# INFO:geometry:	reduced angle potential = 1.6904718659527334.
# INFO:geometry:	reduced angle potential = 0.0033361211419699038.
# INFO:geometry:	reduced angle potential = 0.49543063900960815.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 63 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 225 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 429 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced potential before atom placement: 175.9601716615006
# INFO:geometry:total reduced energy added from growth system: 18.912596041045344
# INFO:geometry:final reduced energy 194.8727677025459
# INFO:geometry:sum of energies: 194.87276770254593
# INFO:geometry:magnitude of difference in the energies: 3.907985046680551e-14
# INFO:geometry:Final logp_proposal: 34.240455774998054
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 3
# INFO:geometry:Atom index proposal order is [25, 26, 24]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# added energy components: [('CustomBondForce', 3.9206685444214333), ('CustomAngleForce', 5.808440549279695), ('CustomTorsionForce', 9.183486947344214)]
# /home/zhangi/miniconda3/envs/perses-sims/lib/python3.7/site-packages/parmed/openmm/topsystem.py:451: OpenMMWarning: Detected incomplete exceptions. Not supported.
#   warnings.warn('Detected incomplete exceptions. Not supported.', OpenMMWarning)
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 61 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 218 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 399 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		there are no Exceptions in the reference system.
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.0875963352323845
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context old positions
# INFO:geometry:There are 3 new atoms
# INFO:geometry:	reduced angle potential = 9.561040338376718e-06.
# INFO:geometry:	reduced angle potential = 2.2331224807285174e-08.
# INFO:geometry:	reduced angle potential = 9.265626886722778e-06.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:geometry:	there are 61 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 218 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 399 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# INFO:geometry:total reduced potential before atom placement: 175.9601716614949
# INFO:geometry:total reduced energy added from growth system: 0.02890879258158345
# INFO:geometry:final reduced energy 175.98908045407646
# INFO:geometry:sum of energies: 175.9890804540765
# INFO:geometry:magnitude of difference in the energies: 3.690103778097864e-14
# INFO:geometry:Final logp_proposal: 14.33910410251057
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# added energy components: [('CustomBondForce', 0.0), ('CustomAngleForce', 0.00025106349275587353), ('CustomTorsionForce', 0.028657729088827577)]

# %%
#create a hybrid topology factory
from perses.annihilation.relative import HybridTopologyFactory
forward_htf = HybridTopologyFactory(topology_proposal=topology_proposal,
             current_positions=pdb.positions,
             new_positions=forward_new_positions,
             repartition=True,
             use_dispersion_correction = False,
             functions=None,
             softcore_alpha = None,
             bond_softening_constant=1.0,
             angle_softening_constant=1.0,
             soften_only_new = False,
             neglected_new_angle_terms = [],
             neglected_old_angle_terms = [],
             softcore_LJ_v2 = True,
             softcore_electrostatics = True,
             softcore_LJ_v2_alpha = 0.85,
             softcore_electrostatics_alpha = 0.3,
             softcore_sigma_Q = 1.0,
             interpolate_old_and_new_14s = False,
             omitted_terms = None)

if not topology_proposal.unique_new_atoms:
    assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
    assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
    vacuum_added_valence_energy = 0.0
else:
    added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

if not topology_proposal.unique_old_atoms:
    assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
    assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
    subtracted_valence_energy = 0.0
else:
    subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), platform = openmm.Platform.getPlatformByName('Reference'))
print(f"zero state error : {zero_state_error}")
print(f"one state error : {one_state_error}")
# Out:
# INFO:relative:Beginning nonbonded method, total particle, barostat, and exceptions retrieval...
# INFO:relative:Old system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:New system forces: dict_keys(['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce'])
# INFO:relative:No unknown forces.
# INFO:relative:Nonbonded method to be used (i.e. from old system): 0
# INFO:relative:Adding and mapping old atoms to hybrid system...
# INFO:relative:Adding and mapping new atoms to hybrid system...
# INFO:relative:No MonteCarloBarostat added.
# INFO:relative:getDefaultPeriodicBoxVectors added to hybrid: [Quantity(value=Vec3(x=2.0, y=0.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=2.0, z=0.0), unit=nanometer), Quantity(value=Vec3(x=0.0, y=0.0, z=2.0), unit=nanometer)]
# INFO:relative:Determined atom classes.
# INFO:relative:Generating old system exceptions dict...
# INFO:relative:Generating new system exceptions dict...
# INFO:relative:Handling constraints...
# INFO:relative:Handling virtual sites...
# INFO:relative:	_handle_virtual_sites: numVirtualSites: 0
# INFO:relative:Adding bond force terms...
# INFO:relative:Adding angle force terms...
# INFO:relative:Adding torsion force terms...
# INFO:relative:Adding nonbonded force terms...
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x2b80b9b53510> > added to hybrid system
# INFO:relative:	_add_nonbonded_force_terms: nonbonded_method is NoCutoff
# INFO:relative:	_add_nonbonded_force_terms: 0 added to standard nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: 0 added to sterics_custom_nonbonded force
# INFO:relative:	_add_nonbonded_force_terms: <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x2b80b9b53660> > added to hybrid system
# INFO:relative:Handling harmonic bonds...
# INFO:relative:	handle_harmonic_bonds: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_bonds: looping through new_system to add relevant terms...
# INFO:relative:Handling harmonic angles...
# INFO:relative:	handle_harmonic_angles: looping through old_system to add relevant terms...
# INFO:relative:	handle_harmonic_angles: looping through new_system to add relevant terms...
# INFO:relative:Handling torsion forces...
# INFO:relative:	handle_periodic_torsion_forces: looping through old_system to add relevant terms...
# INFO:relative:	handle_periodic_torsion_forces: looping through new_system to add relevant terms...
# INFO:relative:Handling nonbonded forces...
# INFO:relative:	handle_nonbonded: looping through all particles in hybrid...
# INFO:relative:	handle_nonbonded: Handling Interaction Groups...
# INFO:relative:	handle_nonbonded: Handling Hybrid Exceptions...
# INFO:relative:	handle_nonbonded: Handling Original Exceptions...
# INFO:relative:Handling unique_new/old interaction exceptions...
# INFO:relative:There are no old/new system exceptions.
# conducting subsequent work with the following platform: Reference
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			HarmonicBondForce: 7.300088837969223
# 			HarmonicAngleForce: 12.445668426678537
# 			PeriodicTorsionForce: 156.2433231894287
# 			NonbondedForce: 4310600.877806889
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			CustomBondForce: 6.606567191188154
# 			HarmonicBondForce: 4.6141901912025
# 			CustomAngleForce: 8.575610737035344
# 			HarmonicAngleForce: 9.67849823892289
# 			CustomTorsionForce: 67.8741581094079
# 			PeriodicTorsionForce: 97.55265202736487
# 			NonbondedForce: 2964932.004295481
# 			CustomNonbondedForce: 1346702.9849827196
# 			CustomNonbondedForce: -1030.6966140471454
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			CustomBondForce: 6.606567191188154
# 			HarmonicBondForce: 4.6141901912025
# 			CustomAngleForce: 8.575610737035344
# 			HarmonicAngleForce: 9.67849823892289
# 			CustomTorsionForce: 67.8741581094136
# 			PeriodicTorsionForce: 97.55265202736487
# 			NonbondedForce: 2964754.124642018
# 			CustomNonbondedForce: 1409488.0903288545
# 			CustomNonbondedForce: -1255.705657323565
# 			AndersenThermostat: 0.0
# Desired platform not supported. exception raised: Error initializing CUDA: CUDA_ERROR_NO_DEVICE (100) at /opt/conda/conda-bld/openmm_1589508244174/work/platforms/cuda/src/CudaContext.cpp:148
# Warning: Returning Reference platform instead of requested platform CUDA
# conducting subsequent work with the following platform: Reference
# 			HarmonicBondForce: 11.220757382390655
# 			HarmonicAngleForce: 18.253857912465474
# 			PeriodicTorsionForce: 165.39815240768976
# 			NonbondedForce: 4373161.020031145
# 			AndersenThermostat: 0.0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-64-35b851aa502d> in <module>
#      35     subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential
#      36
# ---> 37 zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), platform = openmm.Platform.getPlatformByName('Reference'))
#      38 print(f"zero state error : {zero_state_error}")
#      39 print(f"one state error : {one_state_error}")
#
# ~/miniconda3/envs/perses-sims/lib/python3.7/site-packages/perses-0.7.3.dev0-py3.7.egg/perses/tests/utils.py in validate_endstate_energies(topology_proposal, htf, added_energy, subtracted_energy, beta, ENERGY_THRESHOLD, platform, trajectory_directory)
#     802     assert ratio < ENERGY_THRESHOLD, f"The ratio in energy difference for the ZERO state is {ratio}.\n This is greater than the threshold of {ENERGY_THRESHOLD}.\n real-zero: {nonalch_zero_rp} \n alc-zero: {alch_zero_rp} \nadded-valence: {added_energy}"
#     803     ratio = abs((nonalch_one_rp - alch_one_rp + subtracted_energy) / (nonalch_one_rp + alch_one_rp + subtracted_energy))
# --> 804     assert ratio < ENERGY_THRESHOLD, f"The ratio in energy difference for the ONE state is {ratio}.\n This is greater than the threshold of {ENERGY_THRESHOLD}.\n real-one: {nonalch_one_rp} \n alc-one: {alch_one_rp} \nsubtracted-valence: {subtracted_energy}"
#     805
#     806
#
# AssertionError: The ratio in energy difference for the ONE state is 1.995197767511649e-05.
#  This is greater than the threshold of 1e-06.
#  real-one: 4373355.8927988475
#  alc-one: 4373181.410990044
# subtracted-valence: 0.02890879258154655

# %% [markdown]
# the rest of this code is legacy stuff; disregard it

# %%
from simtk import openmm
#######LOGGING#############################
import logging
logging.basicConfig(level = logging.NOTSET)
_logger = logging.getLogger("repartition")
_logger.setLevel(logging.DEBUG)


class RepartitionHybridSystem():
    """
    repartition the hybrid system into forces that are select, interselect, nonselect
    """
    added_forces = {}
    tri_selections = ['select', 'nonselect', 'interselect']
    lambda_caller='lambda_'
    default_select_lambda=1.
    
    #primary nonbonded force
    from openmmtools.constants import ONE_4PI_EPS0 as coulomb_const
    standard_nonbonded_mixing_expression = [
        f"mixer*(U_electrostatics + U_sterics);",
        f"U_sterics = 4*epsilon*((sigma/r)^12-(sigma/r)^6); sigma=0.5*(sigma1+sigma2); epsilon=sqrt(epsilon1*epsilon2);",
        f"U_electrostatics = {coulomb_const}*charge1*charge2/r;",
        f"mixer = lambda_select*selected + lambda_nonselect*nonselected + lambda_interselect*interselected;"]
    primary_nonbonded_template = "4*epsilon*((sigma/r)^12-(sigma/r)^6); sigma=0.5*(sigma1+sigma2); epsilon=sqrt(epsilon1*epsilon2)"
    standard_nonbonded_mixing_expression = "U_sterics = 4*epsilon*x*(x-1.0); x = (sigma/reff_sterics)^6;"
    repartitioned_forces = {}
    
    @classmethod
    def create_system(cls, hybrid_factory, selection_indices):
        """
        initialize a system
        """
        
        #set some attributes
        out_system = openmm.System()
        setattr(cls, 'hybrid_factory', hybrid_factory)
        setattr(cls, 'out_system', out_system)
        setattr(cls, 'in_system', hybrid_factory._hybrid_system)
    
        
        #handle some preliminary stuff
        cls.add_particles(selection_indices)
        cls.add_constraints()
        cls.add_virtual_sites()
        cls.handle_barostat()
        
        #iterate over each force object and attempt to convert the force into 3 forces.
        #add the bond valence forces...
        cls.add_bond_forces()
        cls.handle_bond_forces()
        
        #add the angle valence forces...
        cls.add_angle_forces()
        cls.handle_angle_forces()
        
        #add the torsion valence forces...
        cls.add_torsion_forces()
        cls.handle_torsion_forces()
        
#         for force_name in cls.standard_valence_force_name_maps.keys():
#             cls.add_valence_force(force_name)
#             cls.handle_valence_force(force_name)
        
# #         now for the nonbonded forces...
# #         handle the standard nonbonded force...
#         cls.add_nonbonded_force()
        
        
        return cls.out_system
    
    @classmethod
    def add_particles(cls, selection_indices):
        """
        add particles
        """
        _logger.debug(f"adding particles and creating selection dictionary")
        #add particles
        num_particles = cls.in_system.getNumParticles()
        _logger.debug(f"hybrid system contains {num_particles} particles")
        for particle_idx in range(num_particles):
            mass = cls.in_system.getParticleMass(particle_idx)
            cls.out_system.addParticle(mass)
        
        nonselection_indices = [idx for idx in range(num_particles) if idx not in selection_indices]
        assert set(selection_indices).union(set(nonselection_indices)) == set(range(num_particles))
        setattr(cls, 'select_indices', set(selection_indices))
        setattr(cls, 'nonselect_indices', set(nonselection_indices))
        
        
    
    @classmethod
    def add_box_vectors(cls):
        #copy box vectors
        box_vectors = cls.in_system.getDefaultPeriodicBoxVectors()
        cls.out_system.setDefaultPeriodicBoxVectors(*box_vectors)
    
    @classmethod
    def add_constraints(cls):
        """add constraints"""
        #constraints
        num_constraints = cls.in_system.getNumConstraints()
        _logger.debug(f"adding {num_constraints} constraints")
        
        for constraint_idx in range(num_constraints):
            a0, a1, length=cls.in_system.getConstraintParameters(constraint_idx)
            cls.out_system.addConstraint(a0, a1, length)
    
    @classmethod
    def add_virtual_sites(cls):
        _logger.debug(f"adding virtual sites")
        for particle_idx in range(cls.in_system.getNumParticles()):
            if cls.in_system.isVirtualSite(particle_idx):
                virtual_site = cls.in_system.getVirtualSite(particle_idx)
                cls.out_system.setVirtualSite(particle_idx, virtual_site)
    
    @classmethod
    def handle_barostat(cls):
        import copy
        if 'MonteCarloBarostat' in cls.hybrid_factory._old_system_forces.keys():
            _logger.debug(f"found a MonteCarloBarostat; adding to 'out_system'")
            barostat = copy.deepcopy(cls.hybrid_factory._old_system_forces["MonteCarloBarostat"])
            cls.out_system.addForce(copy_barostat)
        else:
            _logger.debug(f"did not find a MonteCarloBarostat.")
    
    @classmethod
    def add_bond_forces(cls):
        """
        add the appropriate bond forces to the out_system
        """
        custom_bond_force, standard_bond_force = cls.hybrid_factory._hybrid_system_forces['core_bond_force'], cls.hybrid_factory._hybrid_system_forces['standard_bond_force']
        
        #standard_expression
        custom_expression = custom_bond_force.getEnergyFunction()
        
        #define a bond force dict
        bond_force_dict = {}
        
        #params
        num_global_params = custom_bond_force.getNumGlobalParameters()
        num_per_bond_params = custom_bond_force.getNumPerBondParameters()
        
        
        for expression in cls.tri_selections:
            mod_expression = cls.lambda_caller+expression+'*'+custom_expression
            new_force = openmm.CustomBondForce(mod_expression)
            
            #add global params
            for idx in range(num_global_params):
                global_name = custom_bond_force.getGlobalParameterName(idx)
                global_default = custom_bond_force.getGlobalParameterDefaultValue(idx)
                new_force.addGlobalParameter(global_name, global_default)
            
            #then add the lambda_caller
            new_force.addGlobalParameter(cls.lambda_caller+expression, 1.)
            
            #add per bond parameter
            for idx in range(num_per_bond_params):
                per_name = custom_bond_force.getPerBondParameterName(idx)
                new_force.addPerBondParameter(per_name)
                
            bond_force_dict[expression] = new_force
            cls.out_system.addForce(new_force)
        
        cls.added_forces['bonds'] = bond_force_dict
    
    @classmethod
    def add_angle_forces(cls):
        """
        add the appropriate angle forces to the out_system
        """
        custom_angle_force, standard_angle_force = cls.hybrid_factory._hybrid_system_forces['core_angle_force'], cls.hybrid_factory._hybrid_system_forces['standard_angle_force']
        
        #standard_expression
        custom_expression = custom_angle_force.getEnergyFunction()
        
        #define a bond force dict
        angle_force_dict = {}
        
        #params
        num_global_params = custom_angle_force.getNumGlobalParameters()
        num_per_angle_params = custom_angle_force.getNumPerAngleParameters()
        
        for expression in cls.tri_selections:
            mod_expression = cls.lambda_caller+expression+'*'+custom_expression
            new_force = openmm.CustomAngleForce(mod_expression)
            
            #add global params
            for idx in range(num_global_params):
                global_name = custom_angle_force.getGlobalParameterName(idx)
                global_default = custom_angle_force.getGlobalParameterDefaultValue(idx)
                new_force.addGlobalParameter(global_name, global_default)
            
            #then add the lambda_caller
            new_force.addGlobalParameter(cls.lambda_caller+expression, 1.)
            
            #add per bond parameter
            for idx in range(num_per_angle_params):
                per_name = custom_angle_force.getPerAngleParameterName(idx)
                new_force.addPerAngleParameter(per_name)
                
            angle_force_dict[expression] = new_force
            cls.out_system.addForce(new_force)
        
        cls.added_forces['angles'] = angle_force_dict
    
    @classmethod
    def add_torsion_forces(cls):
        """
        add the appropriate torsion forces to the out_system
        """
        custom_torsion_force, standard_torsion_force = cls.hybrid_factory._hybrid_system_forces['custom_torsion_force'], cls.hybrid_factory._hybrid_system_forces['unique_atom_torsion_force']
        
        #standard_expression
        custom_expression = custom_torsion_force.getEnergyFunction()
        
        #define a torsion force dict
        torsion_force_dict = {}
        
        #params
        num_global_params = custom_torsion_force.getNumGlobalParameters()
        num_per_torsion_params = custom_torsion_force.getNumPerTorsionParameters()
        
        for expression in cls.tri_selections:
            #the custom expression is a little bit different here...
            custom_expression_list = custom_expression.split(';') #split the expression by semicolon
            first_expression_entry = custom_expression_list[0] # grab _only_ the first entry in the expression
            mod_first_expression_entry = cls.lambda_caller+expression+'*('+first_expression_entry+')' #scale the entire expression by the lambda selection variable
            custom_expression_list = [mod_first_expression_entry] + custom_expression_list[1:] #all of the other entries in the list are the same
            mod_expression = ';'.join(custom_expression_list) #combine all of the entries

            new_force = openmm.CustomTorsionForce(mod_expression)
            
            #add global params
            for idx in range(num_global_params):
                global_name = custom_torsion_force.getGlobalParameterName(idx)
                global_default = custom_torsion_force.getGlobalParameterDefaultValue(idx)
                new_force.addGlobalParameter(global_name, global_default)
            
            #then add the lambda_caller
            new_force.addGlobalParameter(cls.lambda_caller+expression, 1.)
            
            #add per bond parameter
            for idx in range(num_per_torsion_params):
                per_name = custom_torsion_force.getPerTorsionParameterName(idx)
                new_force.addPerTorsionParameter(per_name)
                torsion_force_dict[expression] = new_force
                
            cls.out_system.addForce(new_force)
        
        cls.added_forces['torsions'] = torsion_force_dict
            
    @classmethod
    def handle_bond_forces(cls):
        """
        iterate through the standard and custom bond force in the hybrid system and add to the new custom bond forces
        """
        custom_bond_force, standard_bond_force = cls.hybrid_factory._hybrid_system_forces['core_bond_force'], cls.hybrid_factory._hybrid_system_forces['standard_bond_force']

        #iterate throug the custom force first
        num_custom_bonds = custom_bond_force.getNumBonds()
        for bond_idx in range(num_custom_bonds):
            p1, p2, [r0_old, k_old, r0_new, k_new] = custom_bond_force.getBondParameters(bond_idx)
            #determine which force it belongs to...
            particle_set = set([p1, p2])
            out_force = cls.query_force_object(force_dict = cls.added_forces['bonds'], query_indices_set = particle_set)
            out_force.addBond(p1, p2, [r0_old, k_old, r0_new, k_new])
        
        #now iterate through the standard bond force
        num_standard_bonds = standard_bond_force.getNumBonds()
        for bond_idx in range(num_standard_bonds):
            p1, p2, r0, k = standard_bond_force.getBondParameters(bond_idx)
            particle_set = set([p1, p2])
            out_force = cls.query_force_object(force_dict = cls.added_forces['bonds'], query_indices_set = particle_set)
            out_force.addBond(p1, p2, [r0, k, r0, k])
        
        #and that's all
    
    @classmethod
    def handle_angle_forces(cls):
        """
        iterate through the standard and custom angle force in the hybrid system and add to the new custom angle forces
        """
        custom_angle_force, standard_angle_force = cls.hybrid_factory._hybrid_system_forces['core_angle_force'], cls.hybrid_factory._hybrid_system_forces['standard_angle_force']

        #iterate throug the custom force first
        num_custom_angles = custom_angle_force.getNumAngles()
        for angle_idx in range(num_custom_angles):
            p1, p2, p3, [theta0_old, k_old, theta0_new, k_new] = custom_angle_force.getAngleParameters(angle_idx)
            #determine which force it belongs to...
            particle_set = set([p1, p2, p3])
            out_force = cls.query_force_object(force_dict = cls.added_forces['angles'], query_indices_set = particle_set)
            out_force.addAngle(p1, p2, p3, [theta0_old, k_old, theta0_new, k_new])
        
        #now iterate through the standard angle force
        num_standard_angles = standard_angle_force.getNumAngles()
        for angle_idx in range(num_standard_angles):
            p1, p2, p3, theta0, k = standard_angle_force.getAngleParameters(angle_idx)
            particle_set = set([p1, p2, p3])
            out_force = cls.query_force_object(force_dict = cls.added_forces['angles'], query_indices_set = particle_set)
            out_force.addAngle(p1, p2, p3, [theta0, k, theta0, k])
        
        #and that's all
    
    @classmethod
    def handle_torsion_forces(cls):
        """
        iterate through the standard and custom torsion forces in the hybrid system and add to the new custom torsion forces
        """
        custom_torsion_force, standard_torsion_force = cls.hybrid_factory._hybrid_system_forces['custom_torsion_force'], cls.hybrid_factory._hybrid_system_forces['unique_atom_torsion_force']
        
        #iterate throug the custom force first
        num_custom_torsions = custom_torsion_force.getNumTorsions()
        for torsion_idx in range(num_custom_torsions):
            p1, p2, p3, p4, [periodicity_old, phase_old, K_old, periodicity_new, phase_new, K_new] = custom_torsion_force.getTorsionParameters(torsion_idx)
            #determine which force it belongs to...
            particle_set = set([p1, p2, p3, p4])
            out_force = cls.query_force_object(force_dict = cls.added_forces['torsions'], query_indices_set = particle_set)
            out_force.addTorsion(p1, p2, p3, p4, [periodicity_old, phase_old, K_old, periodicity_new, phase_new, K_new])
        
        #now iterate through the standard torsion force
        num_standard_torsions = standard_torsion_force.getNumTorsions()
        for torsion_idx in range(num_standard_torsions):
            p1, p2, p3, p4, periodicity, phase, k = standard_torsion_force.getTorsionParameters(torsion_idx)
            particle_set = set([p1, p2, p3, p4])
            out_force = cls.query_force_object(force_dict = cls.added_forces['torsions'], query_indices_set = particle_set)
            out_force.addTorsion(p1, p2, p3, p4, [periodicity, phase, k, periodicity*0., phase*0., k*0.]) #turn off
            out_force.addTorsion(p1, p2, p3, p4, [periodicity*0., phase*0., k*0., periodicity, phase, k]) #turn on
        
        #and that's all
            
    @classmethod    
    def query_force_object(cls, force_dict, query_indices_set):
        """
        return the out force object given a query index set
        """
        if query_indices_set.issubset(cls.select_indices):
            return force_dict['select']
        elif query_indices_set.issubset(cls.nonselect_indices):
            return force_dict['select']
        else:
            assert query_indices_set.intersection(cls.select_indices) != set() and query_indices_set.intersection(cls.nonselect_indices) != set()
            return force_dict['interselect']
    
    @classmethod
    def add_valence_force(cls, force_name):
        """
        NOTE: the standard force does not interpolate parameters whereas the customforce does;
        what we have to do is create 3 of each flavor of force (one for 'select/nonselect/interselect' interaction)
        for each pair of ('HarmonicBondForce/CustomBondForce', 'HarmonicAngleForce/CustomAngleForce', 'PeriodicTorsionForce/CustomTorsionForce'),
        do the following:
        1. pull the appropriate query force (standard/custom)
        2. query the global parameters and per-term parameters
        3. modify the energy function
        4. add the appropriate global params and per particle params to each force
        5. add the lambda_{select/nonselect/interselect}
        6. add the force to the out_system
        """
        _logger.debug(f"adding valence equivalents of {force_name}")
        #get the force index and the force
        custom_valence_force_index = cls.find_valence_custom_force(force_name, cls.custom_expressions[force_name])
        custom_valence_force = cls.force_dict[custom_valence_force_index][1]
        _logger.debug(f"force yanked: {custom_valence_force}")
        
        #tally the number of global params and per bond params
        num_global_params = custom_valence_force.getNumGlobalParameters()
        num_per_term_params = getattr(custom_valence_force, cls.valence_method_query[force_name]['number_per_params'])()
        _logger.debug(f"found {num_global_params} global parameters")
        _logger.debug(f"found {num_per_term_params} per term parameters")
        
        #pbc?
        pbc = custom_valence_force.usesPeriodicBoundaryConditions()
        _logger.debug(f"periodic boundary conditions: {pbc}")
        
        # query the global/per bond parameters
        global_params_values = [(custom_valence_force.getGlobalParameterName(idx), custom_valence_force.getGlobalParameterDefaultValue(idx)) for idx in range(num_global_params)]
        per_term_params = [getattr(custom_valence_force, cls.valence_method_query[force_name]['per_term_parameter_name'])(idx) for idx in range(num_per_term_params)]
        _logger.debug(f"global parameters: {global_params_values}")
        _logger.debug(f"per term parameters: {per_term_params}")
        
        #add a force
        force_expression = cls.custom_expressions[force_name]
        if force_expression is None:
            force_expression = custom_valence_force.getEnergyFunction()
        _logger.debug(f"queried force (energy) expression: {force_expression}")
        
        #make the energy function dependent on lambda_{select/interselect/nonselect}
        splittd_expression = force_expression.split(';')
        mod_first_expression = cls.lambda_caller+'{partition}'+'*('+splittd_expression[0]+')'
        splittd_expression[0] = mod_first_expression
        add_custom_valence_force_expressions = {partition: ';'.join(splittd_expression).format(partition=partition) for partition in cls.tri_template_lambdas}
        _logger.debug(f"custom force expressions: {add_custom_valence_force_expressions}")
        add_custom_valence_forces = {partition: cls.custom_force_templates[force_name](add_custom_valence_force_expressions[partition]) for partition in cls.tri_template_lambdas}
        
        #add corresponding global parameters to the force and per term parameters
        for idx, key in enumerate(add_custom_valence_forces.keys()):
            cforce = add_custom_valence_forces[key]
            _logger.debug(f"adding force: {key} --> {cforce}")
            for param, val in global_params_values:
                _logger.debug(f"global param: {param}; value: {val}")
                cforce.addGlobalParameter(param, val)
            new_global_param = cls.lambda_caller+key
            _logger.debug(f"adding new global param: {new_global_param}")
            cforce.addGlobalParameter(new_global_param, 1.)
            cforce.setUsesPeriodicBoundaryConditions(pbc)
            for param in per_term_params: 
                _logger.debug(f"adding per_term param: {param}")
                getattr(cforce, cls.valence_method_query[force_name]['add_per_param'])(param)
            cls.out_system.addForce(cforce)
        
        cls.added_custom_forces[force_name] = add_custom_valence_forces
    

        
    @classmethod
    def handle_valence_force(cls, force_name):
        """
        copy the appropriate terms over from the standard/custom force and write to the new custom force 
        """
        _logger.debug(f"handling {force_name}")
        
        #get the force index and the force to query
        custom_valence_force_index = cls.find_valence_custom_force(force_name, cls.custom_expressions[force_name])
        custom_query_force = cls.force_dict[custom_valence_force_index][1]
        standard_query_force_index = cls.find_valence_custom_force(cls.standard_valence_force_name_maps[force_name])
        standard_query_force_name, standard_query_force = cls.force_dict[standard_query_force_index]
        _logger.debug(f"querying custom valence force: {custom_query_force}")
        _logger.debug(f"querying standard valence force: {standard_query_force}")
        
        for force in [custom_query_force, standard_query_force]:
            _logger.debug(f"querying {force}")
            custom_type = True if 'Custom' in force.__class__.__name__ else False
            _logger.debug(f"is custom: {custom_type}")

            number_terms = getattr(force, cls.valence_method_query[force_name]['number_terms'])()
            _logger.debug(f"there are {number_terms} in this force")
            num_particles = cls.num_particles_by_force[force_name]
            _logger.debug(f"there are {num_particles} particles in each terms")
            add_forces = cls.added_custom_forces[force_name] #add the force...
            num_per_term_params = getattr(custom_query_force, cls.valence_method_query[custom_query_force.__class__.__name__]['number_per_params'])()
            for term_index in range(number_terms):
                queries = getattr(force, cls.valence_method_query[force_name]['params'])(term_index)
                particles, parameters = queries[:num_particles], queries[num_particles:]
                if custom_type:
                    argument = (*particles, *parameters)
                else:
                    reduced_parameters = []
                    for param in parameters:
                        try:
                            out_param = param/param.unit
                        except Exception as e:
                            out_param = param
                        reduced_parameters.append(out_param)
                        
                    argument = (*particles, reduced_parameters+reduced_parameters)
                    
                _logger.debug(f"particles: {particles}")
                _logger.debug(f"query term parameters: {parameters}")
                _logger.debug(f"add term input: {argument}")
                
                #get the number of per term params...
                assert len(argument[-1]) == num_per_term_params
                
                if set(particles).issubset(set(cls.select_indices)):
                    getattr(add_forces['select'], cls.valence_method_query[force_name]['add_term'])(*argument)
                elif set(particles).issubset(set(cls.nonselect_indices)):
                    #add_forces['nonselect'].addBond(index1, index2, [r0, k, r0, k])
                    getattr(add_forces['nonselect'], cls.valence_method_query[force_name]['add_term'])(*argument)
                else:
                    assert set(particles).intersection(set(cls.nonselect_indices)) != set() and set(particles).intersection(set(cls.select_indices)) != set()
                    #cls.bonded_terms['lambda_interselect'].addBond(index1, index2, [r0, k, r0, k])
                    getattr(add_forces['interselect'], cls.valence_method_query[force_name]['add_term'])(*argument)
         
    @classmethod
    def find_valence_custom_force(cls, custom_force_name, custom_expression_matcher=None):
        force_indices = [idx for idx in cls.force_dict.keys() if cls.force_dict[idx][0] == custom_force_name]
        if custom_expression_matcher is not None:
            particulars_forces = [idx for idx in force_indices if cls.force_dict[idx][1].getEnergyFunction() == custom_expression_matcher]
        else:
            particulars_forces = force_indices
        assert len(particulars_forces) == 1
        return particulars_forces[0]
    
    @classmethod
    def handle_nonbonded_parameters(cls, nonbonded_query_force, to_force):
        #nonbonded method
        nbm = nonbonded_query_force.getNonbondedMethod()
        _logger.debug(f"found nonbondedmethod: {nbm}")
        to_force.setNonbondedMethod(nbm)

        #reaction field dielectric
        try:
            rxn = nonbonded_query_force.getReactionFieldDielectric()
            to_force.setReactionFieldDielectric(rxn)
        except Exception as e:
            _logger.debug(f"failed to query/set reaction field dielectric of {nonbonded_query_force}")
        
    
        #cutoff
        cutoff = nonbonded_query_force.getCutoffDistance()
        to_force.setCutoffDistance(cutoff)
        
        #switching distance
        uses_switch_function = nonbonded_query_force.getUseSwitchingFunction()
        if uses_switch_function:
            distance = nonbonded_query_force.getSwitchingDistance()
            to_force.setUseSwitchingFunction(True)
            to_force.setSwitchingDistance(distance)
        else:
            to_force.setUseSwitchingFunction(False)
        
        #pme and ewald
        try:
            pmeparam = nonbonded_query_force.getPMEParameters()
            ewalderr = nonbonded_query_force.getEwaldErrorTolerance()
            to_force.setPMEParameters(*pmeparam)
            to_force.setEwaldErrorTolerance(ewalderr)
        except Exception as e:
            _logger.debug(f"failed to query/set PME and Ewald parameters of {nonbonded_query_force}")
        
        #dispersion
        try:
            disp = nonbonded_query_force.getUseDispersionCorrection()
            to_force.setUseDispersionCorrection(disp)
        except Exception as e:
            _logger.debug(f"failed to query/set dispersion of {nonbonded_query_force}")
        
        #long range
        try:
            corr = nonbonded_query_force.getUseLongRangeCorrection()
            to_force.setUseLongRangeCorrection(corr)
        except Exception as e:
            _logger.debug(f"failed to query/set long range correction of {nonbonded_query_force}")
    
#     @classmethod
#     def handle_custom_nonbonded_parameters(cls, nonbonded_query_force, to_force):
#         #nbm
#         nbm = nonbonded_query_force.getNonbondedMethod()
#         to_force.setNonbondedMethod(nbm)
        
#         #
    
#     @classmethod
#     def handle_custom_nonbonded_translation(cls, nonbonded_query_force, to_customnonbonded):
#         switch = nonbonded_query_force.getUseSwitchingFunction()
#         to_customnonbonded.setUseSwitchingFunction(switch)
#         switch_distance = nonbonded_query_force.getSwitchingDistance()
#         to_customnonbonded.setSwitchingDistance(switch_distance)
        
#         disp = nonbonded_query_force.getUseDispersionCorrection()
#         to_customnonbonded.setUseLongRangeCorrection(disp)
        
#         nbm = nonbonded_query_force.getNonbondedMethod()
#         to_customnonbonded.setNonbondedMethod(nbm)
    
    @classmethod
    def get_nonselect_expression(cls):
        #make deepcopies of the nonbonded force and add appropriate mixing global params...
        from openmmtools.constants import ONE_4PI_EPS0
        nonselect_expression = "mixer*(U_electrostatics + U_sterics);"
        nonselect_expression += f"U_electrostatics = (1 - select_atoms_bool)*{ONE_4PI_EPS0}*charge_one*charge_two/r;"
        LJ_v2 = cls.hybrid_factory._softcore_LJ_v2
        if LJ_v2:
            nonselect_expression += "U_sterics = select(step(r - r_LJ), 4*epsilon*x*(x-1.0), U_sterics_quad);"
            nonselect_expression += "U_sterics_quad = Force*(((r - r_LJ)^2)/2 - (r - r_LJ)) + U_sterics_cut;"
            nonselect_expression += "U_sterics_cut = 4*epsilon*((sigma/r_LJ)^6)*(((sigma/r_LJ)^6) - 1.0);"
            nonselect_expression += "Force = -4*epsilon*((-12*sigma^12)/(r_LJ^13) + (6*sigma^6)/(r_LJ^7));"
            nonselect_expression += "x = (sigma/r)^6;"
            nonselect_expression += "r_LJ = softcore_alpha*((26/7)*(sigma^6)*lambda_sterics_deprecated)^(1/6);"
            nonselect_expression += "lambda_sterics_deprecated = new_interaction*(1.0 - lambda_sterics_insert) + old_interaction*lambda_sterics_delete;"
        else:
            nonselect_expression = "U_sterics = 4*epsilon*x*(x-1.0); x = (sigma/reff_sterics)^6;"
        
        nonselect_expression += "epsilon = (1-lambda_sterics)*epsilonA + lambda_sterics*epsilonB;" #interpolation
        nonselect_expression += "reff_sterics = sigma*((softcore_alpha*lambda_alpha + (r/sigma)^6))^(1/6);" # effective softcore distance for sterics
        nonselect_expression += "sigma = (1-lambda_sterics)*sigmaA + lambda_sterics*sigmaB;"
        nonselect_expression += "charge_one = q_old1 + lambda_electrostatics * (q_new1 - q_old1);"
        nonselect_expression += "charge_two = q_old2 + lambda_electrostatics * (q_new2 - q_old2);"

        nonselect_expression += "lambda_alpha = new_interaction - new_interaction*lambda_sterics_insert + old_interaction*lambda_sterics_delete;"
        nonselect_expression += "lambda_sterics = core_interaction*lambda_sterics_core + new_interaction*lambda_sterics_insert + old_interaction*lambda_sterics_delete;"
        nonselect_expression += "lambda_electrostatics = core_interaction*lambda_electrostatics_core + new_interaction*lambda_electrostatics_insert + old_interaction*lambda_electrostatics_delete;"
        nonselect_expression += "core_interaction = delta(unique_old1 + unique_old2 + unique_new1 + unique_new2); new_interaction = max(unique_new1, unique_new2); old_interaction = max(unique_old1, unique_old2);"
          
        nonselect_expression += f"mixer = lambda_interselect*interselect_atoms_bool + lambda_nonselect*nonselect_atoms_bool + lambda_select*select_atoms_bool;"
        nonselect_expression += f"interselect_atoms_bool = delta(1 - (is_select1 + is_select2)); nonselect_atoms_bool = delta(is_select1 + is_select2);select_atoms_bool = delta(2 - (is_select1 + is_select2));"
        
        nonselect_expression += "epsilonA = sqrt(epsilonA1*epsilonA2);" # mixing rule for epsilon
        nonselect_expression += "epsilonB = sqrt(epsilonB1*epsilonB2);" # mixing rule for epsilon
        nonselect_expression += "sigmaA = 0.5*(sigmaA1 + sigmaA2);" # mixing rule for sigma
        nonselect_expression += "sigmaB = 0.5*(sigmaB1 + sigmaB2)" # mixing rule for sigma
        
        return nonselect_expression
            
    
    @classmethod
    def add_nonbonded_force(cls):
        """
        the nonbonded forces handle all env forces, (elec and steric.)
        as well as unique new/old 
        """
        _logger.debug(f"handling nonbonded_forces")
        import copy
        
        #retrieve the nonbonded query force...
        nonbonded_force_index = cls.find_valence_custom_force('NonbondedForce')
        nonbonded_query_name, nonbonded_query_force = cls.force_dict[nonbonded_force_index]
        _logger.debug(f"pulled standard nonbonded (electrostatic + env) force from hybrid system")
        
        #retrieve the custom nonbonded query force...
        customnonbonded_force_index = cls.find_valence_custom_force('CustomNonbondedForce')
        customnonbonded_query_name, customnonbonded_query_force = cls.force_dict[customnonbonded_force_index]
        _logger.debug(f"pulled custom nonbonded (steric + env) force from hybrid system")
        
        nonselect_expression = cls.get_nonselect_expression()
        nonbonded_forces = {'select': openmm.NonbondedForce()}
        nonbonded_forces['non_select'] = openmm.CustomNonbondedForce(nonselect_expression)
        for key in ['lambda_nonselect', 'lambda_interselect', 'lambda_select']: nonbonded_forces['non_select'].addGlobalParameter(key, 1.)
        
        #add global variables
        _logger.debug(f"adding global parameters to customnonbonded force")
        nonbonded_forces['non_select'].addGlobalParameter("softcore_alpha", cls.hybrid_factory.softcore_alpha)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_sterics_core", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_electrostatics_core", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_sterics_insert", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_sterics_delete", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_electrostatics_insert", 0.0)
        nonbonded_forces['non_select'].addGlobalParameter("lambda_electrostatics_delete", 0.0)
        
        for key in ['lambda_electrostatics_core', 'lambda_sterics_core', 'lambda_electrostatics_delete', 'lambda_electrostatics_insert']:
            nonbonded_forces['select'].addGlobalParameter(key, 0.)
        #for key in ['lambda_nonselect', 'lambda_interselect', 'lambda_select']: nonbonded_forces['non_select'].addGlobalParameter(key)
        
        #add per particle parameters
        _logger.debug(f"adding per particle parameters to customnonbonded force")
        nonbonded_forces['non_select'].addPerParticleParameter("q_old")
        nonbonded_forces['non_select'].addPerParticleParameter("sigmaA") # Lennard-Jones sigma initial
        nonbonded_forces['non_select'].addPerParticleParameter("epsilonA") # Lennard-Jones epsilon initial
        nonbonded_forces['non_select'].addPerParticleParameter("q_new")
        nonbonded_forces['non_select'].addPerParticleParameter("sigmaB") # Lennard-Jones sigma final
        nonbonded_forces['non_select'].addPerParticleParameter("epsilonB") # Lennard-Jones epsilon final
        nonbonded_forces['non_select'].addPerParticleParameter("unique_old") # 1 = hybrid old atom, 0 otherwise
        nonbonded_forces['non_select'].addPerParticleParameter("unique_new") # 1 = hybrid new atom, 0 otherwise
        nonbonded_forces['non_select'].addPerParticleParameter("is_select") #if it is a selection atom
        
        
        _logger.debug(f"handling nonbonded parameters...")
        cls.handle_nonbonded_parameters(nonbonded_query_force, nonbonded_forces['select'])
        cls.handle_nonbonded_parameters(customnonbonded_query_force, nonbonded_forces['non_select'])
        
        #first, iterate over exceptions...
        num_exceptions = nonbonded_query_force.getNumExceptions()
        num_exception_offsets = nonbonded_query_force.getNumExceptionParameterOffsets()
        exception_offset_exception_indices = [nonbonded_query_force.getExceptionParameterOffset(q)[1] for q in range(num_exception_offsets)]
        num_particle_parameter_offsets = nonbonded_query_force.getNumParticleParameterOffsets()
        num_particles = nonbonded_query_force.getNumParticles()
        assert num_particles == cls.out_system.getNumParticles()
        _logger.debug(f"there are {num_exceptions} standard nonbonded exceptions")
        _logger.debug(f"there are {num_exception_offsets} standard nonbonded offsets")
        _logger.debug(f"there are {num_particle_parameter_offsets} standard nonbonded exception offsets")
        
    
        #first thing to do is add all of the particles to the select_nbf and zero the interactions of all nonselects...
        _logger.debug(f"iterating over particles")
        for particle_idx in range(num_particles):
            #_logger.debug(f"particle: {particle_idx}")
            charge, sigma, epsilon = nonbonded_query_force.getParticleParameters(particle_idx)
            sigmaA, epsilonA, sigmaB, epsilonB, unique_old, unique_new = customnonbonded_query_force.getParticleParameters(particle_idx)
                
            if unique_old == 1:
                assert particle_idx in cls.hybrid_factory._atom_classes['unique_old_atoms']
                #_logger.debug(f"is unique old")
                q_old, q_new = charge, 0.*charge
                assert epsilon/epsilon.unit==0., f"unique old atom has a steric epsilon of {epsilon}"
            elif unique_new == 1:
                assert particle_idx in cls.hybrid_factory._atom_classes['unique_new_atoms']
                #_logger.debug(f"is unique new")
                q_old, q_new = 0*charge, charge
                assert epsilon/epsilon.unit==0., f"unique old atom has a steric epsilon of {epsilon}"
            elif particle_idx in cls.hybrid_factory._atom_classes['core_atoms']:
                #_logger.debug(f"is a core")
                old_idx, new_idx = cls.hybrid_factory._hybrid_to_old_map[particle_idx], cls.hybrid_factory._hybrid_to_new_map[particle_idx]
                [q_old, _, _] = cls.hybrid_factory._old_system_forces['NonbondedForce'].getParticleParameters(old_idx)
                [q_new, _, _] = cls.hybrid_factory._new_system_forces['NonbondedForce'].getParticleParameters(new_idx)
            else: #this is env atom
                #_logger.debug(f"is an environment")
                old_idx, new_idx = cls.hybrid_factory._hybrid_to_old_map[particle_idx], cls.hybrid_factory._hybrid_to_new_map[particle_idx]
                [q_old, sigmaA, epsilonA] = cls.hybrid_factory._old_system_forces['NonbondedForce'].getParticleParameters(old_idx)
                [q_new, sigmaB, epsilonB] = cls.hybrid_factory._new_system_forces['NonbondedForce'].getParticleParameters(new_idx)
                #sanity checks for env atoms
                assert q_old==q_new
                assert sigmaA==sigmaB
                assert epsilonA==epsilonB
                       
            if particle_idx in cls.select_indices:
                #_logger.debug(f"is a selected index")
                is_select=1
                #assert epsilon==0
                if particle_idx in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    assert unique_new==1
                    assert unique_old==0
                    nonbonded_forces['select'].addParticle(0.0, sigma, epsilon*0.0) #start charge at 0
                elif particle_idx in cls.hybrid_factory._atom_classes['unique_old_atoms']:
                    assert unique_new==0
                    assert unique_old==1
                    nonbonded_forces['select'].addParticle(q_old, sigma, epsilon*0.0) #start charge at q_old
                elif particle_idx in cls.hybrid_factory._atom_classes['core_atoms']:
                    assert unique_new==0
                    assert unique_old==0
                    nonbonded_forces['select'].addParticle(q_old, sigma, epsilon*0.0) #start charge at q_old
                elif particle_idx in cls.hybrid_factory._atom_classes['environment_atoms']:
                    assert unique_new==0
                    assert unique_old==0
                    nonbonded_forces['select'].addParticle(q_old, sigma, epsilon)
            else:
                #_logger.debug(f"is a nonselected index")
                is_select=0
                if particle_idx in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    raise Exception(f"unique new atoms must be selected indices")
                elif particle_idx in cls.hybrid_factory._atom_classes['unique_old_atoms']:
                    raise Exception(f"unique old atoms must be selected indices")
                elif particle_idx in cls.hybrid_factory._atom_classes['core_atoms']:
                    raise Exception(f"core atoms must be selected indices")
                elif particle_idx in cls.hybrid_factory._atom_classes['environment_atoms']:
                    nonbonded_forces['select'].addParticle(charge*0., sigma, epsilon*0.) #zero env charges
                else:
                    raise Exception(f"there is a consideration missing")
            
            #regardless, it is added to the non_select custom nonbonded force
            #format is q_old, sigmaA, epsilonA, q_new, sigmaB, epsilonB, unique_old, unique_new, is_select
            nonbonded_forces['non_select'].addParticle([q_old, sigmaA, epsilonA, q_new, sigmaB, epsilonB, unique_old, unique_new, is_select])
        
        #let's just make sure we add the exceptions/exclusions between unique old and new right off the bat
        unique_olds, unique_news = cls.hybrid_factory._atom_classes['unique_old_atoms'], cls.hybrid_factory._atom_classes['unique_new_atoms']
        for old_idx in unique_olds:
            for new_idx in unique_news:
                nonbonded_forces['select'].addException(old_idx, new_idx, 0.0*unit.elementary_charge**2, 1.0*unit.nanometers, 0.0*unit.kilojoules_per_mole)
                nonbonded_forces['non_select'].addExclusion(old_idx, new_idx)
        
        #do the interaction group thing...
        _logger.debug(f"adding interaction group...")
        hf = cls.hybrid_factory
        core_atoms = hf._atom_classes['core_atoms']
        unique_old_atoms = hf._atom_classes['unique_old_atoms']
        unique_new_atoms = hf._atom_classes['unique_new_atoms']
        environment_atoms = hf._atom_classes['environment_atoms']

        nonbonded_forces['non_select'].addInteractionGroup(unique_old_atoms, core_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_old_atoms, environment_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_new_atoms, core_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_new_atoms, environment_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(core_atoms, environment_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(core_atoms, core_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_new_atoms, unique_new_atoms)
        nonbonded_forces['non_select'].addInteractionGroup(unique_old_atoms, unique_old_atoms)
        
        
            
        for exception_idx in range(num_exceptions):
            p1, p2, chargeprod, sigma, epsilon = nonbonded_query_force.getExceptionParameters(exception_idx)
            has_offset = True if exception_idx in exception_offset_exception_indices else False
            #if there is an offset, we can apply the offset to the 
            if set([p1, p2]).issubset(set(cls.select_indices)):      
                if p1 in cls.hybrid_factory._atom_classes['unique_old_atoms'] and p2 in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    #the exception is already handled
                    pass
                elif p2 in cls.hybrid_factory._atom_classes['unique_old_atoms'] and p1 in cls.hybrid_factory._atom_classes['unique_new_atoms']:
                    #the exception is already handled
                    pass
                else:
                    #these could be unique old/new exceptions
                    nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon)
                    nonbonded_forces['non_select'].addExclusion(p1, p2)
                   
            elif set([p1, p2]).issubset(set(cls.nonselect_indices)):
                assert set([p1, p2]).issubset(cls.hybrid_factory._atom_classes['environment_atoms'])
                nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon)
                nonbonded_forces['non_select'].addExclusion(p1, p2)
            else:
                #this is interselect
                #all we can do is to write an exclusions for both in the customnonbonded force and add the exception into the
                #custombondedforce
                nonbonded_forces['select'].addException(p1, p2, chargeprod*0.0, sigma, epsilon*0.0)
                nonbonded_forces['non_select'].addExclusion(p1, p2)
        
        #now that all of the standard exceptions are handled, we have to handle the offsets
        #all of the standard parameter offsets go to the nonbonded electrostatic force
        for param_offset_idx in range(num_particle_parameter_offsets):
            #these are all for electrostatics; the the sterics are zeroed appropriately
            param, particle_idx, chargescale, sigmascale, epsilonscale = nonbonded_query_force.getParticleParameterOffset(param_offset_idx)
            assert particle_idx in cls.select_indices
            nonbonded_forces['select'].addParticleParameterOffset(param, particle_idx, chargescale, sigmascale, epsilonscale)
        for exception_offset_idx in range(num_exception_offsets):
            param, exception_idx, chargeprodscale, sigmascale, epsilonscale = nonbonded_query_force.getExceptionParameterOffset(exception_offset_idx)
            p1, p2, chargeprod, sigma, epsilon = nonbonded_query_force.getExceptionParameters(exception_idx)
            assert set([p1, p2]).issubset(set(cls.select_indices))
            nonbonded_forces['select'].addExceptionParameterOffset(param, exception_idx, chargeprodscale, sigmascale, epsilonscale)
            #the scales should be handled appropriately by the nonselect force
        
        #simply copy the custombondforce and apply to the new repartitioned hybrid system
        custombondforce = cls.hybrid_factory._hybrid_system_forces['old_new_exceptions_force']
        cls.out_system.addForce(copy.deepcopy(custombondforce))
        
        #the last thing to do is to add the forces to the out_system
        cls.out_system.addForce(nonbonded_forces['select'])
        cls.out_system.addForce(nonbonded_forces['non_select'])
            
        
        
            
            
                
                
            
        #then add all of the standard exceptions appropriately
        #TODO: check where the sterics force comes in and also omit the exception if there is a parameter offset
#         for exception_idx in range(num_exceptions):
#             p1, p2, chargeprod, sigma, epsilon = nonbonded_query_force.getExceptionParameters(exception_idx)
            
#             has_offset = True if exception_idx in exception_offset_exception_indices else False
#             if set([p1, p2]).issubset(set(cls.nonselect_indices)) and not has_offset:
#                 #add the exception to the nbforce
#                 nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon) #add the exception to the standard force
#                 nonbonded_forces['non_select'].addExclusion(p1, p2)
#             elif set([p1, p2]).issubset(set(cls.select_indices)) and not has_offset:
#                 nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon) #add the exception to the standard force
#                 #the electrostatics are already handled in the CustomNonbondedForce; do not add an exclusion since this will remove the steric
#             else: #this is interselect. (either with or without an offset...)
#                 #this has to go into the custombondforce...possibly with a 
#                 #nonbonded_forces['select'].addException(p1, p2, chargeprod, sigma, epsilon) #add the exception to the standard force
#                 pass

# %% [markdown]
# have to query the selection indices...

# %% [markdown]
# we have to remove the andersen thermostat

# %%
htf._hybrid_system.getForces()
# Out:
# [<simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7f8c9cce5f30> >,
#  <simtk.openmm.openmm.HarmonicBondForce; proxy of <Swig Object of type 'OpenMM::HarmonicBondForce *' at 0x7f8c9cce5630> >,
#  <simtk.openmm.openmm.CustomAngleForce; proxy of <Swig Object of type 'OpenMM::CustomAngleForce *' at 0x7f8c9cce57b0> >,
#  <simtk.openmm.openmm.HarmonicAngleForce; proxy of <Swig Object of type 'OpenMM::HarmonicAngleForce *' at 0x7f8c9cce5480> >,
#  <simtk.openmm.openmm.CustomTorsionForce; proxy of <Swig Object of type 'OpenMM::CustomTorsionForce *' at 0x7f8c9cce5d50> >,
#  <simtk.openmm.openmm.PeriodicTorsionForce; proxy of <Swig Object of type 'OpenMM::PeriodicTorsionForce *' at 0x7f8c9cce55a0> >,
#  <simtk.openmm.openmm.NonbondedForce; proxy of <Swig Object of type 'OpenMM::NonbondedForce *' at 0x7f8c9cce5600> >,
#  <simtk.openmm.openmm.CustomNonbondedForce; proxy of <Swig Object of type 'OpenMM::CustomNonbondedForce *' at 0x7f8c9cce5660> >,
#  <simtk.openmm.openmm.CustomBondForce; proxy of <Swig Object of type 'OpenMM::CustomBondForce *' at 0x7f8c9cce5ab0> >]

# %%
hybrid_indices = list(htf._atom_classes['unique_old_atoms']) + list(htf._atom_classes['unique_new_atoms']) + list(htf._atom_classes['core_atoms'])

# %%
repartitioned_system = RepartitionHybridSystem.create_system(htf, hybrid_indices)
# Out:
# DEBUG:repartition:adding particles and creating selection dictionary
# DEBUG:repartition:hybrid system contains 29 particles
# DEBUG:repartition:adding 17 constraints
# DEBUG:repartition:adding virtual sites
# DEBUG:repartition:did not find a MonteCarloBarostat.

# %% [markdown]
# can we check the valence terms for matching?

# %%
from openmmtools.states import CompoundThermodynamicState, SamplerState, ThermodynamicState
from perses.annihilation.lambda_protocol import RelativeAlchemicalState, LambdaProtocol
from openmmtools.integrators import LangevinIntegrator
from simtk import unit
from openmmtools import cache
temp = 300 * unit.kelvin
from perses.tests.utils import compute_potential_components
import copy
beta = 1/(kB * temp)
from perses.dispersed.feptasks import minimize

# %%
from coddiwomple.openmm.states import OpenMMPDFState
thermostate = OpenMMPDFState(htf._hybrid_system, alchemical_composability=RelativeAlchemicalState, pressure=None)
particle_state = SamplerState(htf._hybrid_positions, box_vectors = htf._hybrid_system.getDefaultPeriodicBoxVectors())
minimize(thermostate, particle_state)
thermostate.reduced_potential(particle_state)
print(compute_potential_components(thermostate._internal_context, beta=beta))
# Out:
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# [('CustomBondForce', 0.8663907939936045), ('HarmonicBondForce', 0.09473679498248053), ('CustomAngleForce', 1.1646054257891172), ('HarmonicAngleForce', 1.7516283144948863), ('CustomTorsionForce', 0.0), ('PeriodicTorsionForce', 26.244202013777873), ('NonbondedForce', -129.67475505304571), ('CustomNonbondedForce', -2.332954550937813), ('CustomBondForce', 0.0), ('AndersenThermostat', 0.0)]

# %%
new_thermostate = OpenMMPDFState(repartitioned_system, alchemical_composability=RelativeAlchemicalState, pressure=None)
new_thermostate.reduced_potential(particle_state)
print(compute_potential_components(new_thermostate._internal_context, beta=beta))
# Out:
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# [('CustomBondForce', 0.961127588976085), ('CustomBondForce', 0.0), ('CustomBondForce', 0.0), ('CustomAngleForce', 2.9162337402840035), ('CustomAngleForce', 0.0), ('CustomAngleForce', 0.0), ('CustomTorsionForce', 26.244202013777873), ('CustomTorsionForce', 0.0), ('CustomTorsionForce', 0.0), ('AndersenThermostat', 0.0)]

# %%
rep_thermostate = OpenMMPDFState(repartitioned_system, alchemical_composability=RelativeAlchemicalState, pressure=None)
print(compute_potential_components(rep_thermostate._internal_context, beta=beta))
# Out:
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# [('CustomBondForce', 14144.203279073583), ('CustomBondForce', 0.0), ('CustomBondForce', 0.0), ('AndersenThermostat', 0.0)]

# %%
st = '(1-lambda_torsions)*U1 + lambda_torsions*U2;U1 = K1*(1+cos(periodicity1*theta-phase1));U2 = K2*(1+cos(periodicity2*theta-phase2));'

# %%
st.split(';')
# Out:
# ['(1-lambda_torsions)*U1 + lambda_torsions*U2',
#  'U1 = K1*(1+cos(periodicity1*theta-phase1))',
#  'U2 = K2*(1+cos(periodicity2*theta-phase2))',
#  '']

# %%
class Dummy:
    _var = 1.
    def __init__(self):
        pass
    def ret(self):
        print(self._var)

# %%
c = Dummy()

# %%
c.ret()
# Out:
# 1.0
